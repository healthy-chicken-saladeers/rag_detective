# %% [markdown]
# # 66% Balanced Consensus: BERT-Based Financial Sentiment Classifier
#
# This document provides an explanation of the python script used to train a classifier on top of a BERT model via fine-tuning. The task is financial sentiment analysis, where sentences are classified into three sentiments: negative, neutral, and positive.
#
# ## Dataset
#
# The dataset is [hosted on Hugging Face,](https://huggingface.co/datasets/financial_phrasebank) where you can find further information on its curation, motivation, and annotation.
#
# ### Overview
#
# The dataset consists of 4846 lines, each containing a financial text sentence and its corresponding sentiment, separated by an '@' symbol. The sentiment can belong to one of three categories: Negative, Neutral, or Positive, and is distributed as:
#
# - Neutral: 2879 entries (59%)
# - Positive: 1363 entries (28%)
# - Negative: 604 entries (12.4%)
#
# ### Data Fields
#
# - **sentence**: A tokenized line from the dataset.
# - **label**: A label representing the sentence class as a string: 'positive', 'negative', or 'neutral'.
#
# ### Data Splits
#
# Although the dataset does not come with predefined training/validation/test splits, the sentences are categorized into different configurations based on the degree of agreement among the annotators:
#
# - **sentences_50agree**: Number of instances with >= 50% annotator agreement - 4846 sentences
# - **sentences_66agree**: Number of instances with >= 66% annotator agreement - 4217 sentences
# - **sentences_75agree**: Number of instances with >= 75% annotator agreement - 3453 sentences
# - **sentences_allagree**: Number of instances with 100% annotator agreement - 2264 sentences
#
# For this project, we use the `sentences_50agree` configuration comprising of 4846 instances and manually split it into training, validation, and testing sets in a 70-15-15 proportion.
#
# All sentences in the dataset are limited to fewer than 512 tokens, in accordance with the BERT model's input constraints.
#
# ## Imports and System Setup
#
# The first part of the code includes importing necessary modules and setting up the TensorFlow environment to recognize accessible GPU devices.
#
#
# ## Metrics
#
# The model's performance after training is evaluated based on accuracy and F1 score. Accuracy measures the proportion of correct predictions, while the F1 score provides a harmonic mean between precision and recall, hammered down for individual classes.
#
# F1 score is calculated after each epoch by a custom F1_Evaluation class that uses the Scikit-learn function `f1_score()` for calculation.
#
# We took the extra step of tracking the F1 score for the validation set for a few reasons due to using a financial dataset:
#
# - **Handling Imbalance**: Financial datasets often exhibit class imbalance. For instance, genuine transactions significantly outnumber fraudulent ones. Accuracy can be misleading in such cases, making F1 a more balanced metric as it considers both precision and recall.
#
# - **Balancing Costs**: Both false negatives (e.g., overlooking a negative sentiment) and false positives (e.g., misclassifying a neutral statement as negative) have implications. The F1 score ensures a balance between reducing these two error types.
#
# - **Threshold Tuning**: Financial decisions can involve adjustable thresholds. The F1 score can guide optimization, ensuring neither precision nor recall is neglected.
#
# ## Wandb
#
# [Wandb (Weights & Biases)](https://wandb.ai/site) is used for experiment tracking.
#
# ## Preprocessing
#
# The data is read from the .txt file. The file encoding is first detected using the `chardet` library, and then the data is loaded into a pandas DataFrame using the detected encoding. The DataFrame contains two columns: sentence and label.
#
# Then the data is split into train, validation, and test sets, stratifying on the label to respect the original distribution of classes in the dataset.
#
# The `BertTokenizer` is used to encode the sentences into format suitable for the BERT model. `truncation=True` and `padding=True` ensures that all sequences are of the same length.
#
# The tokenized sentence encodings and the corresponding labels are wrapped into TensorFlow's `Dataset` objects.
#
# ## Model Creation
#
# The existing BERT model ('bert-base-uncased') from HuggingFace's transformer models is loaded for sequence classification with 3 labels (negative, neutral, positive).
#
# ## Model Compilation and Training
#
# The model is compiled with Adam optimizer, `SparseCategoricalCrossentropy` loss function, and accuracy as a metric. We use `SparseCategoricalCrossentropy` as this is a  multi-class classification with integer labels (not one-hot encoded). It's memory-efficient, especially for many classes, and pairs with a softmax activation in the model's output.
#
# A Wandb run is initialized, and the data is fit on the model using a batch size of 8 for 10 epochs. The validation data and the custom F1 score calculation callback are also passed in the fit method.
#
# ## Evaluation
#
# The model is evaluated on the test set. Classification report and F1 score are printed to show detailed information about performance on all three categories. The F1 score is also logged to the Wandb run.

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 26.1 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=296466b1901bd78949380df73a3e432eb2f36e284df3a364a48846e4c5251e6b
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.40 docker-pycreds-0.4.0 gitdb-4.0.11 pathtools-0.1.2 sentry-sdk-1.32.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.15.12

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 97.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
# Easy place to track what we're training
WHICH_DATASET = 'Sentences_66Agree.txt'
WHICH_RUN_NAME = 'bert-balanced-66Agree'
seed_val = 42

# Import necessary libraries
import os

# Used to suppress output for F1 validation calculation
import io
import contextlib

# For encoding detection
import chardet

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import train_test_split

# Hugging Face Transformers for BERT
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import BertConfig, BertTokenizer, TFBertForSequenceClassification


# Deep learning frameworks
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import MeanSquaredError, SparseCategoricalCrossentropy
import tensorflow.keras.backend as K


# Ensure we have a GPU
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Verify current GPU
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

# Weights and Biases for tracking experiments
import wandb
from wandb.keras import WandbCallback
from sklearn.metrics import f1_score

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Num GPUs Available:  1
# Found GPU at: /device:GPU:0
# Mounted at /content/drive

# %% [markdown]
# # Prepare Data
#
# ## Overview
#
# The varying levels of annotator agreements creates an unusual challenge. The aim is to create a train, test, and validation split that does not bias the model towards obvious sentiments. This guide will describe each step in the data splitting process.
#
# ## Step 1: Load the Data
#
# Firstly we load the dataset files (which are text files in this case). Considering the possibility that these text files might have different encodings (they initially crashed the program as they use `ISO-8859-1`), we use Python's `chardet` library to detect the encoding before reading the file. This ensures that the loading of files doesn't fail due to encoding issues. The data is then shuffled randomly. The shuffling was an easy thing to miss, as previously we had used `train_test_split` from `scikit-learn` to split the data, and it had automatically shuffled the data. The data actually comes nearly sorted by sentiment, so without shuffling the model can't be fine-tuned at all.
#
# The files are read in the following way:
# - Every sentence in the dataset is separated by an '@' delimiter.
# - There are no headers in the files so they are assigned later as ['sentence', 'label'].
# - We use pandas' `read_csv` function to read these files.
#
# ## Step 2: Create a Subset from 'sentences_50agree'
#
# The `sentences_50agree` dataset is the largest and most diverse dataset. To avoid overfitting and create a diverse validation set, we create a subset from this dataframe that will later be used for validation/testing. This subset is the same size as the train set.
#
# ## Step 3: Split the Subset into Validation and Test Sets
#
# The subset created from `sentences_50agree` is split into validation and test sets. Here, a stratified sampling is performed to ensure that the split datasets have instances of each class ('positive', 'negative', and 'neutral') in proportions close to their original distribution in the parent dataset. The dataset is split in such way that 31% data is used for validation/testing. We choose 31% as this seems to result in the closest to a 70/15/15 train/validate/test split once the datasets have been assembled.
#
# ## Step 4: Update the Training Set
#
# After obtaining the validation and test sets, we remove sentences present in these sets from the training set. This is done to avoid data leakage and ensure that the model doesn't see any sentence in the training phase that it would later encounter in the validation/testing phase.
#
# ## Step 5: Further Divide the Validation and Test Sets
#
# The validation/test set subset is then divided equally into two parts: one part forms the validation set and the other part forms the test set.
#
# ## Step 6: Output the Sizes and Percentages
#
# Finally, after creating all the datasets, we output the sizes of the train, validation, and test datasets along with their respective percentages to make sure that the classes are as balanced as they can be given the data.
#
# This completes our data splitting process ensuring that we have a good mix of data in each dataset and our model does not get biased towards the easy-to-identify financial sentiments.

# %%
# Load a dataset given its path
def load_data(data_path, seed):
    raw_data = open(data_path, 'rb').read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']
    print("Encoding for:", data_path, "is:", encoding)
    df = pd.read_csv(data_path, delimiter='@', header=None, names=['sentence', 'label'], encoding=encoding)
    return df.sample(frac=1, random_state=seed)

# Load data with correct encoding and delimiter
df_50agree = load_data('Sentences_50Agree.txt', seed_val)
train = load_data(WHICH_DATASET, seed_val)

# Save original count for unit testing purposes
original_50agree_count = train.shape[0]

# Take a random subset of sentences_50agree equal in size to the size of train dataset
subset_50agree = df_50agree.sample(n=len(train), random_state=seed_val)

# Randomly choose 31% of the data from this subset for validation/test
_, valid_test_subset = train_test_split(subset_50agree, test_size=0.31, random_state=seed_val, stratify=subset_50agree['label'])

# Remove items from train dataset that are in the validation/test set
train = train[~train['sentence'].isin(valid_test_subset['sentence'])]

# Split the validation/test set in half into validation and test set
valid, test = train_test_split(valid_test_subset, test_size=0.5, random_state=seed_val, stratify=valid_test_subset['label'])

# Load pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Convert texts to BERT input format
train_encodings = tokenizer(train.sentence.tolist(), truncation=True, padding=True)
val_encodings = tokenizer(valid.sentence.tolist(), truncation=True, padding=True)
test_encodings = tokenizer(test.sentence.tolist(), truncation=True, padding=True)

def make_tf_dataset(encodings, labels):
    """Function to convert encodings and labels into tensorflow dataset."""
    input_ids = np.array(encodings['input_ids'])
    attention_mask = np.array(encodings['attention_mask'])
    labels = np.array(labels)
    return tf.data.Dataset.from_tensor_slices((input_ids, attention_mask, labels)).map(
        lambda input_ids, attention_mask, labels : ({"input_ids": input_ids, "attention_mask": attention_mask}, labels))

# Defining the labels keys and their respective values as per the model
label2num = {'negative':0,'neutral':1,'positive':2}
train_labels = [label2num[x] for x in train.label.tolist()]
val_labels = [label2num[x] for x in valid.label.tolist()]
test_labels = [label2num[x] for x in test.label.tolist()]

# Convert encodings and labels into tensorflow dataset
train_dataset = make_tf_dataset(train_encodings, train_labels)
val_dataset = make_tf_dataset(val_encodings, val_labels)
test_dataset = make_tf_dataset(test_encodings, test_labels)

# Print the sizes and percentages
total_size = len(train) + len(valid) + len(test)

print("\nSize of Train set:", len(train),
      f"({(len(train)/total_size)*100:.2f}%)")
print("Size of Validation set:", len(valid),
      f"({(len(valid)/total_size)*100:.2f}%)")
print("Size of Test set:", len(test),
      f"({(len(test)/total_size)*100:.2f}%)")
# Out:
# Encoding for: Sentences_50Agree.txt is: ISO-8859-1
# Encoding for: Sentences_66Agree.txt is: ISO-8859-1
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Size of Train set: 3084 (70.22%)
# Size of Validation set: 654 (14.89%)
# Size of Test set: 654 (14.89%)

# %% [markdown]
# # Check out the distribution of the classes to ensure they look balanced across datasets

# %%
# Distribution in the Training set
print("Training set:")
print(train['label'].value_counts())

# Distribution in the Validation set
print("\nValidation set:")
print(valid['label'].value_counts())

# Distribution in the Test set
print("\nTest set:")
print(test['label'].value_counts())
# Out:
# Training set:
# neutral     1854
# positive     852
# negative     378
# Name: label, dtype: int64
#
# Validation set:
# neutral     388
# positive    186
# negative     80
# Name: label, dtype: int64
#
# Test set:
# neutral     388
# positive    185
# negative     81
# Name: label, dtype: int64

# %% [markdown]
# # F1 Callback to track F1 Validation for BERT

# %%
# Custom callback for F1 evaluation at the end of each epoch
class F1_Evaluation(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=(), interval=1):
        super(F1_Evaluation, self).__init__()
        self.interval = interval
        self.dataset = validation_data
        self.X_val, self.y_val = [], []

        # Iterating over the dataset to get batches
        for batch in self.dataset:
            # Batch consists of inputs and labels
            inputs, labels = batch
            self.X_val.append(inputs)  # inputs is a dict with keys ['input_ids', 'attention_mask']
            self.y_val.append(np.atleast_1d(np.squeeze(labels.numpy())))  # Converting labels tensor to numpy array

        self.f1_scores = []

    def on_epoch_end(self, epoch, logs={}):
        """Method called at the end of each epoch, calculating and logging F1 score."""
        print("\nCalculating validation F1 score...")
        # Process only for epochs with (epoch number modulo self.interval) equal to 0
        if epoch % self.interval == 0:
            y_pred = []

            # Iterate over inputs for each batch to generate predictions
            for X_val_batch in self.X_val:
                # Redirect stdout and stderr to avoid print statements inside keras.model.predict
                with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()):
                    y_pred_single = self.model.predict(X_val_batch).logits
                # Softmax on logits and take class with maximum probability
                y_pred_single = tf.nn.softmax(y_pred_single).numpy().argmax(axis=-1)
                # Ensure that y_pred_single is at least a 1D array even if it is a scalar
                y_pred.append(np.atleast_1d(y_pred_single))

            # Concatenate all predictions and labels
            y_pred = np.concatenate(y_pred)
            y_val = np.concatenate(self.y_val)

            # Calculate F1 score and append to F1 scores list
            _f1 = f1_score(y_val, y_pred, average='weighted')
            self.f1_scores.append(_f1)

            print("Epoch: {} - validation_data f1_score: {:.4f}".format(epoch+1, _f1))

             # Log the validation F1 score at the end of each epoch
            wandb.log({"val_f1_score": _f1})

# %% [markdown]
# # Distillation

# %%
teacher_model = TFBertForSequenceClassification.from_pretrained("/content/drive/My Drive/my_bert_model")
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at /content/drive/My Drive/my_bert_model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
# CONSTANTS
VOCAB_SIZE = 30522 # same as BERT's vocab size
NUM_EPOCHS = 20    # Number of epochs to train over
EMBEDDING_DIM = 64 # dimension of the word embeddings
HIDDEN_DIM = 128   # hidden dimension of LSTM
OUTPUT_DIM = 3.    # number of classes in the classification task (negative, neutral, positive)
DROPOUT_RATE = 0.5 # dropout rate
ALPHA = 0.5        # the factor to weigh the cross entropy and mean squared error loss

# %% [markdown]
# ### LSTM

# %%
class F1_Evaluation_LSTM(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=(), y_true=[], interval=1):
        super(F1_Evaluation_LSTM, self).__init__()
        self.interval = interval
        self.X_val = validation_data  # Here validation_data should be X_valid
        self.y_val = y_true  # Here y_true should be the proper class labels you pass during function call
        self.f1_scores = []

    def on_epoch_end(self, epoch, logs={}):
        print("\nCalculating validation F1 score...")
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val)
            y_pred = tf.nn.softmax(y_pred).numpy().argmax(axis=-1)
            _f1 = f1_score(self.y_val, y_pred, average='weighted')
            self.f1_scores.append(_f1)
            print("Epoch: {} - validation_data f1_score: {:.4f}".format(epoch+1, _f1))
            # Log the validation F1 score at the end of each epoch
            wandb.log({"val_f1_score": _f1})

# %%
wandb.login()

# Define the LSTMDistilled model class
class LSTMDistilled(tf.keras.Model):
    def __init__(self,
                 vocab_size=30522,
                 embedding_dim=64,
                 lstm_units = 128,
                 output_dim=3,
                 dropout=0.5,
                 alpha=0.5):
        super(LSTMDistilled, self).__init__()

        self.embedding = Embedding(vocab_size, embedding_dim)
        self.dropout = Dropout(dropout)
        self.lstm = LSTM(lstm_units, return_sequences=False)
        self.lstm = Bidirectional(self.lstm, merge_mode='concat')
        self.dropout = Dropout(dropout)
        self.fc = Dense(output_dim)
        self.alpha = alpha

    def call(self, x):
        x = self.embedding(x)
        x = self.dropout(x)
        x = self.lstm(x)
        x = self.dropout(x)
        x = self.fc(x)
        return x

    def loss_fn(self, y_true, y_pred):
        criterion_mse = MeanSquaredError()
        criterion_ce = SparseCategoricalCrossentropy(from_logits=True)

        y_true_cls = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)  # get the class index
        y_true_one_hot = tf.one_hot(y_true_cls, depth=3)

        return self.alpha * criterion_ce(y_true_cls, y_pred) + (1 - self.alpha) * criterion_mse(y_true_one_hot, tf.nn.softmax(y_pred))

    def model(self):
        x = tf.keras.Input(shape=(None,))
        return tf.keras.Model(inputs=[x], outputs=self.call(x))
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
def train_lstm_distilled(temperature=3.0, alpha=ALPHA):

  # Initializing wandb run
  wandb.init(project="bert-sentiment", name=f'LSTM Distill t={str(temperature)} a={str(alpha)}')

  # Compute teacher's logits
  teacher_logits_train = teacher_model.predict(train_dataset.batch(8)).logits
  teacher_logits_val = teacher_model.predict(val_dataset.batch(8)).logits

  # Compute teacher's softened probabilities using temperature
  teacher_probs_train = tf.nn.softmax(teacher_logits_train / temperature)
  teacher_probs_val = tf.nn.softmax(teacher_logits_val / temperature)

  # Initialize tokenizer with max number of words to VOCAB_SIZE
  # The LSTM uses different tokenization than the BERT model
  lstm_tokenizer = Tokenizer(num_words=VOCAB_SIZE)

  # Fit the tokenizer on your text
  lstm_tokenizer.fit_on_texts(train.sentence.tolist())

  # Tokenize the text into sequences
  sequences_train = lstm_tokenizer.texts_to_sequences(train.sentence.tolist())
  sequences_valid = lstm_tokenizer.texts_to_sequences(valid.sentence.tolist())
  sequences_test = lstm_tokenizer.texts_to_sequences(test.sentence.tolist())

  # Pad sequences for equal input lengths
  X_train = pad_sequences(sequences_train, maxlen=128, padding='post')
  X_valid = pad_sequences(sequences_valid, maxlen=128, padding='post')
  X_test = pad_sequences(sequences_test, maxlen=128, padding='post')


  # Construct LSTM with constants as parameters as defined above
  lstm_distilled = LSTMDistilled(
      vocab_size=VOCAB_SIZE,
      embedding_dim=EMBEDDING_DIM,
      lstm_units=HIDDEN_DIM,
      output_dim=OUTPUT_DIM,
      dropout=DROPOUT_RATE,
      alpha=ALPHA
  )

  student_model = lstm_distilled.model()

  # Compile model with custom loss
  student_model.compile(optimizer='adam',
                        loss=lstm_distilled.loss_fn,
                        metrics=['accuracy'])

  # Create callback for F1 score
  f1_evaluation = F1_Evaluation_LSTM(validation_data=X_valid, y_true=np.argmax(teacher_probs_val, axis=1), interval=1)

  # Train LSTM as a student model
  lstm_history = student_model.fit(
      X_train,
      teacher_probs_train,
      validation_data=(X_valid, teacher_probs_val),
      epochs=NUM_EPOCHS,
      verbose=2,
      callbacks=[WandbCallback(save_model=False), f1_evaluation]

  )

  # Extract the true labels from the test dataset
  y_test = test.label.map(label2num).values

  # Predict the labels for the test dataset using the lstm_distilled student model
  y_pred_test = tf.nn.softmax(student_model.predict(X_test)).numpy().argmax(axis=-1)

  print(classification_report(y_test, y_pred_test, target_names=['negative', 'neutral', 'positive']))

  # Calculate the weighted F1 score for the test dataset
  test_f1_score = f1_score(y_test, y_pred_test, average='weighted')
  print("Test F1 Score:", test_f1_score)

  # Log the test F1 score to wandb
  wandb.log({'test_f1_score': test_f1_score})

  return student_model, lstm_history, f1_evaluation.f1_scores

# %%
def plot_training_process(history, f1_scores):
    fig, axs = plt.subplots(2, 2, figsize=(18, 8),
                            gridspec_kw={'height_ratios': [2, 1]})

    # Collapse the subplots for the F1 scores into a single subplot
    axs[1, 0].remove()
    axs[1, 1].remove()

    # Plotting training and validation loss
    axs[0, 0].plot(history.history["loss"], label='Train')
    axs[0, 0].plot(history.history["val_loss"], label='Validation')
    axs[0, 0].set_title("Model Loss")
    axs[0, 0].set_ylabel("Loss")
    axs[0, 0].set_xlabel("Epoch")
    axs[0, 0].legend()

    # Plotting training and validation accuracy
    axs[0, 1].plot(history.history["accuracy"], label='Train')
    if "val_accuracy" in history.history:
        axs[0, 1].plot(history.history["val_accuracy"], label='Validation')
    axs[0, 1].set_title("Model Accuracy")
    axs[0, 1].set_ylabel("Accuracy")
    axs[0, 1].set_xlabel("Epoch")
    axs[0, 1].legend()

    # Plotting Validation F1 Scores
    ax2 = fig.add_subplot(2, 1, 2)  # 2x1, occupying the second slot.
    ax2.plot(f1_scores)
    ax2.set_title("Validation F1 Score")
    ax2.set_ylabel("F1 Score")
    ax2.set_xlabel("Epoch")
    ax2.legend(["F1 Score"], loc="upper left")

    # Improve layout and show plots
    plt.subplots_adjust(hspace=0.6)
    plt.show()

# %% [markdown]
# ## BERT

# %%
class DistillBert(tf.keras.Model):
    def __init__(self, bert_model, alpha=0.5):
        super(DistillBert, self).__init__()
        self.bert_model = bert_model
        self.alpha = alpha

    def call(self, inputs):
        return self.bert_model(inputs)

    def loss_fn(self, y_true, y_pred):
        batch_size = K.shape(y_pred)[0]
        y_true_hard = K.reshape(K.argmax(y_true, axis=-1), shape=(batch_size, 1))

        hard_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)(y_true_hard, y_pred)
        soft_loss = tf.keras.losses.KLDivergence()(y_true, tf.nn.softmax(y_pred))

        return self.alpha * hard_loss + (1.0 - self.alpha) * soft_loss

# %%
def train_bert_distilled(temperature=3.0, alpha=ALPHA):
  # Initializing wandb run
  wandb.init(project="bert-sentiment", name=f'BERT Distill t={str(temperature)} a={str(alpha)}')

  # Compute teacher's logits and probabilities
  teacher_logits_train = teacher_model.predict(train_dataset.batch(8)).logits
  teacher_logits_val = teacher_model.predict(val_dataset.batch(8)).logits
  teacher_probs_train = tf.nn.softmax(teacher_logits_train / temperature)
  teacher_probs_val = tf.nn.softmax(teacher_logits_val / temperature)

  # Define student model with custom BERT configuration of 6 layers
  student_config = BertConfig.from_pretrained('bert-base-uncased', num_hidden_layers=6)
  student_config.num_labels = 3
  student_model = TFBertForSequenceClassification(student_config)

  # Initialize distilled BERT model.
  student_model = DistillBert(student_model)

  # Convert teacher's probabilities to TF Dataset
  teacher_probs_train_dataset = tf.data.Dataset.from_tensor_slices(teacher_probs_train)
  teacher_probs_val_dataset = tf.data.Dataset.from_tensor_slices(teacher_probs_val)

  # Combine the given datasets with teacher probabilities as labels
  bert_train_dataset = tf.data.Dataset.zip((train_dataset, teacher_probs_train_dataset))
  bert_val_dataset = tf.data.Dataset.zip((val_dataset, teacher_probs_val_dataset))

  # Define learning rate schedule
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
      initial_learning_rate=3e-5,
      decay_steps=10000,
      decay_rate=0.9)
  optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

  # Compile the model
  student_model.compile(optimizer=optimizer, loss=student_model.loss_fn, metrics=['accuracy'])

  # Prepare for F1 score evaluation
  f1_evaluation = F1_Evaluation(validation_data=val_dataset.batch(8), interval=1)

  # Train the BERT model
  dilbert_history = student_model.fit(bert_train_dataset.batch(8),
                                  validation_data=bert_val_dataset.batch(8),
                                  epochs=NUM_EPOCHS, verbose=1,
                                  callbacks=[WandbCallback(save_model=False), f1_evaluation] #, early_stopping]
  )

  # Evaluate the model with test dataset and show the classification report
  y_test = test.label.map(label2num).values
  y_pred = tf.nn.softmax(student_model.predict(test_dataset.batch(8)).logits).numpy().argmax(axis=-1)

  print(classification_report(y_test, y_pred, target_names=['negative', 'neutral', 'positive']))
  test_f1_score = f1_score(y_test, y_pred, average='weighted')
  print("F1 Score:", test_f1_score)

  # Log the test F1 score to wandb (single data point)
  wandb.log({'test_f1_score': test_f1_score})

  return student_model, dilbert_history, f1_evaluation.f1_scores

# %% [markdown]
# # LSTM

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=1.0, alpha=0.5)
# Out:
# wandb: Currently logged in as: iankelk. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_160011-gv6k6g5y</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/gv6k6g5y' target="_blank">LSTM Distill t=1.0 a=0.5</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/gv6k6g5y' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/gv6k6g5y</a>
# 386/386 [==============================] - 19s 27ms/step
# 82/82 [==============================] - 6s 27ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.6354
# 97/97 - 27s - loss: 0.5207 - accuracy: 0.6232 - val_loss: 0.4366 - val_accuracy: 0.6911 - 27s/epoch - 282ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 2 - validation_data f1_score: 0.6592
# 97/97 - 8s - loss: 0.4739 - accuracy: 0.6971 - val_loss: 0.4081 - val_accuracy: 0.7080 - 8s/epoch - 80ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 3 - validation_data f1_score: 0.7134
# 97/97 - 6s - loss: 0.3232 - accuracy: 0.7730 - val_loss: 0.3809 - val_accuracy: 0.7569 - 6s/epoch - 61ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 4 - validation_data f1_score: 0.7410
# 97/97 - 3s - loss: 0.2396 - accuracy: 0.8314 - val_loss: 0.3747 - val_accuracy: 0.7615 - 3s/epoch - 30ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7798
# 97/97 - 3s - loss: 0.1600 - accuracy: 0.8894 - val_loss: 0.3713 - val_accuracy: 0.7859 - 3s/epoch - 35ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 6 - validation_data f1_score: 0.8003
# 97/97 - 3s - loss: 0.1291 - accuracy: 0.9287 - val_loss: 0.3521 - val_accuracy: 0.8073 - 3s/epoch - 31ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 7 - validation_data f1_score: 0.7775
# 97/97 - 3s - loss: 0.0757 - accuracy: 0.9604 - val_loss: 0.3972 - val_accuracy: 0.7859 - 3s/epoch - 34ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 8 - validation_data f1_score: 0.7927
# 97/97 - 3s - loss: 0.0461 - accuracy: 0.9767 - val_loss: 0.3948 - val_accuracy: 0.7997 - 3s/epoch - 29ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 9 - validation_data f1_score: 0.8022
# 97/97 - 2s - loss: 0.0322 - accuracy: 0.9818 - val_loss: 0.4187 - val_accuracy: 0.8089 - 2s/epoch - 25ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 10 - validation_data f1_score: 0.7927
# 97/97 - 2s - loss: 0.0226 - accuracy: 0.9887 - val_loss: 0.4770 - val_accuracy: 0.7951 - 2s/epoch - 23ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7829
# 97/97 - 2s - loss: 0.0244 - accuracy: 0.9861 - val_loss: 0.4475 - val_accuracy: 0.7859 - 2s/epoch - 21ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 12 - validation_data f1_score: 0.8013
# 97/97 - 3s - loss: 0.0194 - accuracy: 0.9919 - val_loss: 0.4590 - val_accuracy: 0.8058 - 3s/epoch - 28ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 13 - validation_data f1_score: 0.8043
# 97/97 - 3s - loss: 0.0117 - accuracy: 0.9948 - val_loss: 0.5089 - val_accuracy: 0.8119 - 3s/epoch - 31ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 14 - validation_data f1_score: 0.7994
# 97/97 - 2s - loss: 0.0117 - accuracy: 0.9935 - val_loss: 0.4976 - val_accuracy: 0.8043 - 2s/epoch - 21ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 15 - validation_data f1_score: 0.8066
# 97/97 - 3s - loss: 0.0131 - accuracy: 0.9935 - val_loss: 0.4937 - val_accuracy: 0.8119 - 3s/epoch - 29ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 16 - validation_data f1_score: 0.8007
# 97/97 - 2s - loss: 0.0166 - accuracy: 0.9919 - val_loss: 0.4821 - val_accuracy: 0.8028 - 2s/epoch - 24ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 17 - validation_data f1_score: 0.8030
# 97/97 - 2s - loss: 0.0217 - accuracy: 0.9880 - val_loss: 0.4966 - val_accuracy: 0.8073 - 2s/epoch - 21ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 18 - validation_data f1_score: 0.8037
# 97/97 - 2s - loss: 0.0118 - accuracy: 0.9932 - val_loss: 0.4803 - val_accuracy: 0.8058 - 2s/epoch - 22ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 19 - validation_data f1_score: 0.7957
# 97/97 - 2s - loss: 0.0077 - accuracy: 0.9964 - val_loss: 0.5099 - val_accuracy: 0.7982 - 2s/epoch - 25ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 20 - validation_data f1_score: 0.8048
# 97/97 - 2s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.5736 - val_accuracy: 0.8104 - 2s/epoch - 24ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.77      0.44      0.56        81
#      neutral       0.79      0.86      0.82       388
#     positive       0.65      0.66      0.66       185
#
#     accuracy                           0.75       654
#    macro avg       0.74      0.65      0.68       654
# weighted avg       0.75      0.75      0.74       654
#
# Test F1 Score: 0.7444796206106331

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=1.0, alpha=0.7)
# Out:
# Finishing last run (ID:gv6k6g5y) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▅▆▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▇▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▂▅▅▆█▆▇█▇▆████▇██▇█</td></tr><tr><td>val_f1_score</td><td>▁▂▄▅▇█▇▇█▇▇█████████</td></tr><tr><td>val_loss</td><td>▄▃▂▂▂▁▂▂▃▅▄▄▆▆▅▅▆▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99935</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.35211</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.00281</td></tr><tr><td>test_f1_score</td><td>0.74448</td></tr><tr><td>val_accuracy</td><td>0.8104</td></tr><tr><td>val_f1_score</td><td>0.8048</td></tr><tr><td>val_loss</td><td>0.57357</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=1.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/gv6k6g5y' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/gv6k6g5y</a><br/> View job at <a href='https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v6' target="_blank">https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v6</a><br/>Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_160011-gv6k6g5y/logs</code>
# Successfully finished last run (ID:gv6k6g5y). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_160218-jbzsqd4n</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/jbzsqd4n' target="_blank">LSTM Distill t=1.0 a=0.7</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/jbzsqd4n' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/jbzsqd4n</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 26ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.5698
# 97/97 - 19s - loss: 0.5247 - accuracy: 0.6206 - val_loss: 0.4604 - val_accuracy: 0.6575 - 19s/epoch - 195ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 2 - validation_data f1_score: 0.7047
# 97/97 - 7s - loss: 0.3764 - accuracy: 0.7357 - val_loss: 0.3914 - val_accuracy: 0.7462 - 7s/epoch - 70ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 3 - validation_data f1_score: 0.6367
# 97/97 - 4s - loss: 0.2792 - accuracy: 0.8090 - val_loss: 0.4520 - val_accuracy: 0.6820 - 4s/epoch - 41ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 4 - validation_data f1_score: 0.7114
# 97/97 - 3s - loss: 0.2614 - accuracy: 0.8152 - val_loss: 0.4056 - val_accuracy: 0.7477 - 3s/epoch - 34ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 5 - validation_data f1_score: 0.7563
# 97/97 - 3s - loss: 0.1695 - accuracy: 0.8836 - val_loss: 0.3924 - val_accuracy: 0.7676 - 3s/epoch - 28ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 6 - validation_data f1_score: 0.7670
# 97/97 - 3s - loss: 0.1097 - accuracy: 0.9368 - val_loss: 0.4141 - val_accuracy: 0.7706 - 3s/epoch - 32ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 7 - validation_data f1_score: 0.7848
# 97/97 - 2s - loss: 0.0612 - accuracy: 0.9650 - val_loss: 0.5053 - val_accuracy: 0.7920 - 2s/epoch - 23ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 8 - validation_data f1_score: 0.8039
# 97/97 - 3s - loss: 0.0459 - accuracy: 0.9741 - val_loss: 0.4173 - val_accuracy: 0.8073 - 3s/epoch - 29ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 9 - validation_data f1_score: 0.7851
# 97/97 - 3s - loss: 0.0273 - accuracy: 0.9861 - val_loss: 0.4821 - val_accuracy: 0.7859 - 3s/epoch - 27ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 10 - validation_data f1_score: 0.8009
# 97/97 - 3s - loss: 0.0227 - accuracy: 0.9874 - val_loss: 0.5162 - val_accuracy: 0.8043 - 3s/epoch - 27ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7975
# 97/97 - 2s - loss: 0.0209 - accuracy: 0.9899 - val_loss: 0.5153 - val_accuracy: 0.8012 - 2s/epoch - 22ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 12 - validation_data f1_score: 0.7922
# 97/97 - 2s - loss: 0.0176 - accuracy: 0.9893 - val_loss: 0.4955 - val_accuracy: 0.7920 - 2s/epoch - 21ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 13 - validation_data f1_score: 0.7964
# 97/97 - 3s - loss: 0.0154 - accuracy: 0.9919 - val_loss: 0.5507 - val_accuracy: 0.8028 - 3s/epoch - 28ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 14 - validation_data f1_score: 0.7730
# 97/97 - 2s - loss: 0.0116 - accuracy: 0.9951 - val_loss: 0.5847 - val_accuracy: 0.7798 - 2s/epoch - 24ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 15 - validation_data f1_score: 0.7911
# 97/97 - 2s - loss: 0.0106 - accuracy: 0.9948 - val_loss: 0.5234 - val_accuracy: 0.7936 - 2s/epoch - 21ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 16 - validation_data f1_score: 0.7851
# 97/97 - 2s - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.6045 - val_accuracy: 0.7920 - 2s/epoch - 21ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 17 - validation_data f1_score: 0.7858
# 97/97 - 2s - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.6056 - val_accuracy: 0.7936 - 2s/epoch - 24ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 18 - validation_data f1_score: 0.7868
# 97/97 - 2s - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.6615 - val_accuracy: 0.7936 - 2s/epoch - 21ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 19 - validation_data f1_score: 0.7722
# 97/97 - 2s - loss: 0.0214 - accuracy: 0.9893 - val_loss: 0.5023 - val_accuracy: 0.7737 - 2s/epoch - 22ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 20 - validation_data f1_score: 0.7800
# 97/97 - 2s - loss: 0.0123 - accuracy: 0.9938 - val_loss: 0.5351 - val_accuracy: 0.7813 - 2s/epoch - 22ms/step
# 21/21 [==============================] - 0s 6ms/step
#               precision    recall  f1-score   support
#
#     negative       0.57      0.60      0.59        81
#      neutral       0.80      0.82      0.81       388
#     positive       0.67      0.61      0.64       185
#
#     accuracy                           0.73       654
#    macro avg       0.68      0.68      0.68       654
# weighted avg       0.73      0.73      0.73       654
#
# Test F1 Score: 0.7326180747453165

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=1.0, alpha=0.3)
# Out:
# Finishing last run (ID:jbzsqd4n) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▅▅▆▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▂▅▆▆▇█▇██▇█▇▇▇▇▇▆▇</td></tr><tr><td>val_f1_score</td><td>▁▅▃▅▇▇▇█▇████▇█▇▇▇▇▇</td></tr><tr><td>val_loss</td><td>▃▁▃▁▁▂▄▂▃▄▄▄▅▆▄▇▇█▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99384</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.39136</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.01229</td></tr><tr><td>test_f1_score</td><td>0.73262</td></tr><tr><td>val_accuracy</td><td>0.78135</td></tr><tr><td>val_f1_score</td><td>0.78005</td></tr><tr><td>val_loss</td><td>0.53507</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=1.0 a=0.7</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/jbzsqd4n' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/jbzsqd4n</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_160218-jbzsqd4n/logs</code>
# Successfully finished last run (ID:jbzsqd4n). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_160406-wj5bbxjl</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/wj5bbxjl' target="_blank">LSTM Distill t=1.0 a=0.3</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/wj5bbxjl' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/wj5bbxjl</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 26ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.6177
# 97/97 - 20s - loss: 0.5259 - accuracy: 0.6161 - val_loss: 0.4567 - val_accuracy: 0.6667 - 20s/epoch - 201ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 2 - validation_data f1_score: 0.7056
# 97/97 - 6s - loss: 0.3806 - accuracy: 0.7299 - val_loss: 0.3866 - val_accuracy: 0.7446 - 6s/epoch - 63ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 3 - validation_data f1_score: 0.7029
# 97/97 - 4s - loss: 0.2802 - accuracy: 0.8084 - val_loss: 0.3931 - val_accuracy: 0.7431 - 4s/epoch - 39ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 4 - validation_data f1_score: 0.7353
# 97/97 - 4s - loss: 0.2096 - accuracy: 0.8495 - val_loss: 0.3793 - val_accuracy: 0.7554 - 4s/epoch - 37ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 5 - validation_data f1_score: 0.7638
# 97/97 - 3s - loss: 0.1391 - accuracy: 0.9154 - val_loss: 0.4154 - val_accuracy: 0.7768 - 3s/epoch - 30ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 6 - validation_data f1_score: 0.7904
# 97/97 - 3s - loss: 0.0846 - accuracy: 0.9520 - val_loss: 0.4062 - val_accuracy: 0.7951 - 3s/epoch - 31ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 7 - validation_data f1_score: 0.7640
# 97/97 - 3s - loss: 0.0637 - accuracy: 0.9679 - val_loss: 0.4872 - val_accuracy: 0.7768 - 3s/epoch - 26ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 8 - validation_data f1_score: 0.7862
# 97/97 - 3s - loss: 0.0524 - accuracy: 0.9718 - val_loss: 0.3927 - val_accuracy: 0.7905 - 3s/epoch - 29ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 9 - validation_data f1_score: 0.7966
# 97/97 - 2s - loss: 0.0285 - accuracy: 0.9899 - val_loss: 0.4474 - val_accuracy: 0.7997 - 2s/epoch - 23ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 10 - validation_data f1_score: 0.7986
# 97/97 - 3s - loss: 0.0211 - accuracy: 0.9912 - val_loss: 0.5044 - val_accuracy: 0.8043 - 3s/epoch - 27ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7826
# 97/97 - 2s - loss: 0.0317 - accuracy: 0.9861 - val_loss: 0.4645 - val_accuracy: 0.7875 - 2s/epoch - 24ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 12 - validation_data f1_score: 0.7969
# 97/97 - 2s - loss: 0.0211 - accuracy: 0.9890 - val_loss: 0.4978 - val_accuracy: 0.7997 - 2s/epoch - 22ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 13 - validation_data f1_score: 0.7906
# 97/97 - 3s - loss: 0.0143 - accuracy: 0.9932 - val_loss: 0.5080 - val_accuracy: 0.7951 - 3s/epoch - 28ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 14 - validation_data f1_score: 0.7740
# 97/97 - 2s - loss: 0.0109 - accuracy: 0.9951 - val_loss: 0.6568 - val_accuracy: 0.7844 - 2s/epoch - 24ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 15 - validation_data f1_score: 0.8066
# 97/97 - 2s - loss: 0.0137 - accuracy: 0.9935 - val_loss: 0.5544 - val_accuracy: 0.8104 - 2s/epoch - 22ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 16 - validation_data f1_score: 0.8046
# 97/97 - 3s - loss: 0.0067 - accuracy: 0.9955 - val_loss: 0.5422 - val_accuracy: 0.8089 - 3s/epoch - 26ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 17 - validation_data f1_score: 0.8048
# 97/97 - 2s - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.5779 - val_accuracy: 0.8089 - 2s/epoch - 22ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 18 - validation_data f1_score: 0.8021
# 97/97 - 2s - loss: 0.0076 - accuracy: 0.9968 - val_loss: 0.5588 - val_accuracy: 0.8058 - 2s/epoch - 23ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 19 - validation_data f1_score: 0.8061
# 97/97 - 2s - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.5998 - val_accuracy: 0.8104 - 2s/epoch - 25ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 20 - validation_data f1_score: 0.7944
# 97/97 - 2s - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.5941 - val_accuracy: 0.7982 - 2s/epoch - 21ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.74      0.42      0.54        81
#      neutral       0.78      0.84      0.81       388
#     positive       0.64      0.66      0.65       185
#
#     accuracy                           0.74       654
#    macro avg       0.72      0.64      0.66       654
# weighted avg       0.73      0.74      0.73       654
#
# Test F1 Score: 0.7290312213923067

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=2.0, alpha=0.5)
# Out:
# Finishing last run (ID:wj5bbxjl) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▅▅▆▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▆▇▆▇▇█▇▇▇▇█████▇</td></tr><tr><td>val_f1_score</td><td>▁▄▄▅▆▇▆▇██▇█▇▇██████</td></tr><tr><td>val_loss</td><td>▃▁▁▁▂▂▄▁▃▄▃▄▄█▅▅▆▆▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99838</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.37927</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.00374</td></tr><tr><td>test_f1_score</td><td>0.72903</td></tr><tr><td>val_accuracy</td><td>0.79817</td></tr><tr><td>val_f1_score</td><td>0.79441</td></tr><tr><td>val_loss</td><td>0.59415</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=1.0 a=0.3</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/wj5bbxjl' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/wj5bbxjl</a><br/> View job at <a href='https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v7' target="_blank">https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v7</a><br/>Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_160406-wj5bbxjl/logs</code>
# Successfully finished last run (ID:wj5bbxjl). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_160550-7o9qs7pl</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/7o9qs7pl' target="_blank">LSTM Distill t=2.0 a=0.5</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/7o9qs7pl' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/7o9qs7pl</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 25ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.6295
# 97/97 - 19s - loss: 0.5150 - accuracy: 0.6352 - val_loss: 0.4491 - val_accuracy: 0.6942 - 19s/epoch - 192ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 2 - validation_data f1_score: 0.6871
# 97/97 - 7s - loss: 0.3755 - accuracy: 0.7435 - val_loss: 0.3895 - val_accuracy: 0.7355 - 7s/epoch - 69ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 3 - validation_data f1_score: 0.7029
# 97/97 - 5s - loss: 0.2817 - accuracy: 0.7980 - val_loss: 0.3979 - val_accuracy: 0.7416 - 5s/epoch - 49ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 4 - validation_data f1_score: 0.7062
# 97/97 - 4s - loss: 0.2149 - accuracy: 0.8379 - val_loss: 0.4009 - val_accuracy: 0.7508 - 4s/epoch - 46ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7274
# 97/97 - 2s - loss: 0.1667 - accuracy: 0.8794 - val_loss: 0.4237 - val_accuracy: 0.7462 - 2s/epoch - 25ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 6 - validation_data f1_score: 0.7870
# 97/97 - 2s - loss: 0.1055 - accuracy: 0.9342 - val_loss: 0.4655 - val_accuracy: 0.7951 - 2s/epoch - 24ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 7 - validation_data f1_score: 0.7924
# 97/97 - 2s - loss: 0.0588 - accuracy: 0.9695 - val_loss: 0.4229 - val_accuracy: 0.7982 - 2s/epoch - 25ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 8 - validation_data f1_score: 0.7941
# 97/97 - 2s - loss: 0.0418 - accuracy: 0.9786 - val_loss: 0.4959 - val_accuracy: 0.7997 - 2s/epoch - 24ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 9 - validation_data f1_score: 0.7930
# 97/97 - 3s - loss: 0.0325 - accuracy: 0.9815 - val_loss: 0.4639 - val_accuracy: 0.7982 - 3s/epoch - 29ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 10 - validation_data f1_score: 0.7773
# 97/97 - 2s - loss: 0.0318 - accuracy: 0.9835 - val_loss: 0.4862 - val_accuracy: 0.7752 - 2s/epoch - 24ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7844
# 97/97 - 2s - loss: 0.0207 - accuracy: 0.9896 - val_loss: 0.5137 - val_accuracy: 0.7905 - 2s/epoch - 24ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 12 - validation_data f1_score: 0.7847
# 97/97 - 2s - loss: 0.0229 - accuracy: 0.9874 - val_loss: 0.5139 - val_accuracy: 0.7890 - 2s/epoch - 22ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 13 - validation_data f1_score: 0.7753
# 97/97 - 2s - loss: 0.0146 - accuracy: 0.9929 - val_loss: 0.5790 - val_accuracy: 0.7798 - 2s/epoch - 21ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 14 - validation_data f1_score: 0.7917
# 97/97 - 3s - loss: 0.0113 - accuracy: 0.9942 - val_loss: 0.6134 - val_accuracy: 0.7966 - 3s/epoch - 31ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 15 - validation_data f1_score: 0.7852
# 97/97 - 2s - loss: 0.0094 - accuracy: 0.9958 - val_loss: 0.6220 - val_accuracy: 0.7890 - 2s/epoch - 24ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 16 - validation_data f1_score: 0.7715
# 97/97 - 2s - loss: 0.0119 - accuracy: 0.9935 - val_loss: 0.6173 - val_accuracy: 0.7783 - 2s/epoch - 20ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 17 - validation_data f1_score: 0.7802
# 97/97 - 2s - loss: 0.0103 - accuracy: 0.9948 - val_loss: 0.6017 - val_accuracy: 0.7859 - 2s/epoch - 22ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 18 - validation_data f1_score: 0.7785
# 97/97 - 2s - loss: 0.0145 - accuracy: 0.9919 - val_loss: 0.5481 - val_accuracy: 0.7783 - 2s/epoch - 23ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 19 - validation_data f1_score: 0.7756
# 97/97 - 2s - loss: 0.0104 - accuracy: 0.9942 - val_loss: 0.5479 - val_accuracy: 0.7768 - 2s/epoch - 22ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 20 - validation_data f1_score: 0.7823
# 97/97 - 2s - loss: 0.0134 - accuracy: 0.9935 - val_loss: 0.5737 - val_accuracy: 0.7859 - 2s/epoch - 23ms/step
# 21/21 [==============================] - 0s 6ms/step
#               precision    recall  f1-score   support
#
#     negative       0.68      0.42      0.52        81
#      neutral       0.80      0.82      0.81       388
#     positive       0.62      0.68      0.65       185
#
#     accuracy                           0.73       654
#    macro avg       0.70      0.64      0.66       654
# weighted avg       0.73      0.73      0.73       654
#
# Test F1 Score: 0.7277437621148951

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=2.0, alpha=0.7)
# Out:
# Finishing last run (ID:7o9qs7pl) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▅▆▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▄▅▄████▆▇▇▇█▇▇▇▇▆▇</td></tr><tr><td>val_f1_score</td><td>▁▃▄▄▅████▇██▇██▇▇▇▇▇</td></tr><tr><td>val_loss</td><td>▃▁▁▁▂▃▂▄▃▄▅▅▇███▇▆▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99351</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.38946</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.01337</td></tr><tr><td>test_f1_score</td><td>0.72774</td></tr><tr><td>val_accuracy</td><td>0.78593</td></tr><tr><td>val_f1_score</td><td>0.78231</td></tr><tr><td>val_loss</td><td>0.5737</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=2.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/7o9qs7pl' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/7o9qs7pl</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_160550-7o9qs7pl/logs</code>
# Successfully finished last run (ID:7o9qs7pl). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_160740-dqer98cr</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/dqer98cr' target="_blank">LSTM Distill t=2.0 a=0.7</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/dqer98cr' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/dqer98cr</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 26ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.6135
# 97/97 - 20s - loss: 0.5145 - accuracy: 0.6310 - val_loss: 0.4516 - val_accuracy: 0.6758 - 20s/epoch - 204ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 2 - validation_data f1_score: 0.7039
# 97/97 - 7s - loss: 0.3757 - accuracy: 0.7335 - val_loss: 0.3847 - val_accuracy: 0.7462 - 7s/epoch - 75ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 3 - validation_data f1_score: 0.7136
# 97/97 - 5s - loss: 0.2760 - accuracy: 0.8129 - val_loss: 0.3838 - val_accuracy: 0.7508 - 5s/epoch - 49ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 4 - validation_data f1_score: 0.7235
# 97/97 - 4s - loss: 0.2172 - accuracy: 0.8427 - val_loss: 0.4122 - val_accuracy: 0.7523 - 4s/epoch - 41ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7525
# 97/97 - 3s - loss: 0.1505 - accuracy: 0.8920 - val_loss: 0.4211 - val_accuracy: 0.7599 - 3s/epoch - 31ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 6 - validation_data f1_score: 0.7605
# 97/97 - 2s - loss: 0.0979 - accuracy: 0.9403 - val_loss: 0.4297 - val_accuracy: 0.7630 - 2s/epoch - 24ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 7 - validation_data f1_score: 0.7809
# 97/97 - 2s - loss: 0.0609 - accuracy: 0.9663 - val_loss: 0.4287 - val_accuracy: 0.7905 - 2s/epoch - 21ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 8 - validation_data f1_score: 0.7822
# 97/97 - 3s - loss: 0.0380 - accuracy: 0.9812 - val_loss: 0.5113 - val_accuracy: 0.7859 - 3s/epoch - 27ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 9 - validation_data f1_score: 0.7971
# 97/97 - 3s - loss: 0.0311 - accuracy: 0.9815 - val_loss: 0.4334 - val_accuracy: 0.7997 - 3s/epoch - 28ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 10 - validation_data f1_score: 0.7979
# 97/97 - 3s - loss: 0.0216 - accuracy: 0.9899 - val_loss: 0.5134 - val_accuracy: 0.8012 - 3s/epoch - 27ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 11 - validation_data f1_score: 0.7927
# 97/97 - 3s - loss: 0.0216 - accuracy: 0.9887 - val_loss: 0.4947 - val_accuracy: 0.7966 - 3s/epoch - 26ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 12 - validation_data f1_score: 0.7748
# 97/97 - 3s - loss: 0.0188 - accuracy: 0.9916 - val_loss: 0.5410 - val_accuracy: 0.7737 - 3s/epoch - 27ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 13 - validation_data f1_score: 0.7907
# 97/97 - 2s - loss: 0.0126 - accuracy: 0.9951 - val_loss: 0.5300 - val_accuracy: 0.7920 - 2s/epoch - 22ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 14 - validation_data f1_score: 0.7888
# 97/97 - 2s - loss: 0.0141 - accuracy: 0.9912 - val_loss: 0.5230 - val_accuracy: 0.7936 - 2s/epoch - 24ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 15 - validation_data f1_score: 0.7886
# 97/97 - 2s - loss: 0.0135 - accuracy: 0.9932 - val_loss: 0.5296 - val_accuracy: 0.7890 - 2s/epoch - 22ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 16 - validation_data f1_score: 0.7825
# 97/97 - 3s - loss: 0.0063 - accuracy: 0.9961 - val_loss: 0.6556 - val_accuracy: 0.7920 - 3s/epoch - 28ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 17 - validation_data f1_score: 0.7873
# 97/97 - 2s - loss: 0.0109 - accuracy: 0.9948 - val_loss: 0.5703 - val_accuracy: 0.7890 - 2s/epoch - 21ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 18 - validation_data f1_score: 0.7822
# 97/97 - 2s - loss: 0.0114 - accuracy: 0.9955 - val_loss: 0.5006 - val_accuracy: 0.7829 - 2s/epoch - 24ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 19 - validation_data f1_score: 0.7991
# 97/97 - 2s - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.5602 - val_accuracy: 0.8028 - 2s/epoch - 21ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 20 - validation_data f1_score: 0.7669
# 97/97 - 2s - loss: 0.0097 - accuracy: 0.9945 - val_loss: 0.5882 - val_accuracy: 0.7676 - 2s/epoch - 20ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.64      0.40      0.49        81
#      neutral       0.82      0.78      0.80       388
#     positive       0.59      0.75      0.66       185
#
#     accuracy                           0.72       654
#    macro avg       0.68      0.64      0.65       654
# weighted avg       0.73      0.72      0.72       654
#
# Test F1 Score: 0.7212896900052159

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=2.0, alpha=0.3)
# Out:
# Finishing last run (ID:dqer98cr) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.818 MB of 3.818 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▅▆▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▆▆▇▇███▆▇▇▇▇▇▇█▆</td></tr><tr><td>val_f1_score</td><td>▁▄▅▅▆▇▇▇███▇███▇█▇█▇</td></tr><tr><td>val_loss</td><td>▃▁▁▂▂▂▂▄▂▄▄▅▅▅▅█▆▄▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99449</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.38378</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.00971</td></tr><tr><td>test_f1_score</td><td>0.72129</td></tr><tr><td>val_accuracy</td><td>0.76758</td></tr><tr><td>val_f1_score</td><td>0.76687</td></tr><tr><td>val_loss</td><td>0.5882</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=2.0 a=0.7</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/dqer98cr' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/dqer98cr</a><br/> View job at <a href='https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v8' target="_blank">https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v8</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_160740-dqer98cr/logs</code>
# Successfully finished last run (ID:dqer98cr). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_160928-cadiv5ow</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/cadiv5ow' target="_blank">LSTM Distill t=2.0 a=0.3</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/cadiv5ow' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/cadiv5ow</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 26ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.6292
# 97/97 - 18s - loss: 0.5300 - accuracy: 0.6219 - val_loss: 0.4625 - val_accuracy: 0.6743 - 18s/epoch - 184ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 2 - validation_data f1_score: 0.6797
# 97/97 - 6s - loss: 0.3814 - accuracy: 0.7292 - val_loss: 0.4033 - val_accuracy: 0.7309 - 6s/epoch - 67ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 3 - validation_data f1_score: 0.7162
# 97/97 - 5s - loss: 0.2808 - accuracy: 0.8090 - val_loss: 0.3832 - val_accuracy: 0.7554 - 5s/epoch - 55ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 4 - validation_data f1_score: 0.7602
# 97/97 - 3s - loss: 0.2093 - accuracy: 0.8531 - val_loss: 0.3824 - val_accuracy: 0.7676 - 3s/epoch - 34ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7831
# 97/97 - 2s - loss: 0.1223 - accuracy: 0.9235 - val_loss: 0.4475 - val_accuracy: 0.7936 - 2s/epoch - 25ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 6 - validation_data f1_score: 0.7785
# 97/97 - 3s - loss: 0.1132 - accuracy: 0.9335 - val_loss: 0.3966 - val_accuracy: 0.7768 - 3s/epoch - 35ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 7 - validation_data f1_score: 0.7971
# 97/97 - 3s - loss: 0.0528 - accuracy: 0.9711 - val_loss: 0.4049 - val_accuracy: 0.8012 - 3s/epoch - 29ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 8 - validation_data f1_score: 0.8012
# 97/97 - 2s - loss: 0.0331 - accuracy: 0.9822 - val_loss: 0.4670 - val_accuracy: 0.8012 - 2s/epoch - 24ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 9 - validation_data f1_score: 0.8035
# 97/97 - 2s - loss: 0.0268 - accuracy: 0.9857 - val_loss: 0.4576 - val_accuracy: 0.8028 - 2s/epoch - 21ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 10 - validation_data f1_score: 0.7862
# 97/97 - 2s - loss: 0.0241 - accuracy: 0.9870 - val_loss: 0.5307 - val_accuracy: 0.7936 - 2s/epoch - 25ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7977
# 97/97 - 3s - loss: 0.0192 - accuracy: 0.9906 - val_loss: 0.4804 - val_accuracy: 0.7982 - 3s/epoch - 26ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 12 - validation_data f1_score: 0.7816
# 97/97 - 2s - loss: 0.0123 - accuracy: 0.9929 - val_loss: 0.5127 - val_accuracy: 0.7844 - 2s/epoch - 22ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 13 - validation_data f1_score: 0.7963
# 97/97 - 2s - loss: 0.0084 - accuracy: 0.9964 - val_loss: 0.5691 - val_accuracy: 0.7997 - 2s/epoch - 24ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 14 - validation_data f1_score: 0.7960
# 97/97 - 2s - loss: 0.0096 - accuracy: 0.9945 - val_loss: 0.5614 - val_accuracy: 0.7982 - 2s/epoch - 24ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 15 - validation_data f1_score: 0.8030
# 97/97 - 2s - loss: 0.0151 - accuracy: 0.9922 - val_loss: 0.5902 - val_accuracy: 0.8089 - 2s/epoch - 21ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 16 - validation_data f1_score: 0.7948
# 97/97 - 2s - loss: 0.0146 - accuracy: 0.9922 - val_loss: 0.5337 - val_accuracy: 0.7997 - 2s/epoch - 25ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 17 - validation_data f1_score: 0.7850
# 97/97 - 2s - loss: 0.0084 - accuracy: 0.9961 - val_loss: 0.5878 - val_accuracy: 0.7875 - 2s/epoch - 24ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 18 - validation_data f1_score: 0.7866
# 97/97 - 2s - loss: 0.0503 - accuracy: 0.9737 - val_loss: 0.4450 - val_accuracy: 0.7875 - 2s/epoch - 18ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 19 - validation_data f1_score: 0.7992
# 97/97 - 2s - loss: 0.0202 - accuracy: 0.9909 - val_loss: 0.4924 - val_accuracy: 0.8012 - 2s/epoch - 24ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 20 - validation_data f1_score: 0.7819
# 97/97 - 2s - loss: 0.0125 - accuracy: 0.9945 - val_loss: 0.5214 - val_accuracy: 0.7813 - 2s/epoch - 20ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.61      0.46      0.52        81
#      neutral       0.82      0.76      0.79       388
#     positive       0.61      0.77      0.68       185
#
#     accuracy                           0.73       654
#    macro avg       0.68      0.66      0.67       654
# weighted avg       0.74      0.73      0.73       654
#
# Test F1 Score: 0.727797271827342

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=5.0, alpha=0.5)
# Out:
# Finishing last run (ID:cadiv5ow) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▅▇▇██████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▂▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▆███▇▇▇█▇██▇▇█▇</td></tr><tr><td>val_f1_score</td><td>▁▃▄▆▇▇███▇█▇████▇▇█▇</td></tr><tr><td>val_loss</td><td>▄▂▁▁▃▁▂▄▄▆▄▅▇▇█▆█▃▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99449</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.3824</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.01247</td></tr><tr><td>test_f1_score</td><td>0.7278</td></tr><tr><td>val_accuracy</td><td>0.78135</td></tr><tr><td>val_f1_score</td><td>0.78191</td></tr><tr><td>val_loss</td><td>0.52138</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=2.0 a=0.3</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/cadiv5ow' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/cadiv5ow</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_160928-cadiv5ow/logs</code>
# Successfully finished last run (ID:cadiv5ow). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_161112-kt36cz9b</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/kt36cz9b' target="_blank">LSTM Distill t=5.0 a=0.5</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/kt36cz9b' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/kt36cz9b</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 26ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 6ms/step
# Epoch: 1 - validation_data f1_score: 0.6199
# 97/97 - 21s - loss: 0.5135 - accuracy: 0.6362 - val_loss: 0.4512 - val_accuracy: 0.6865 - 21s/epoch - 216ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 2 - validation_data f1_score: 0.6743
# 97/97 - 7s - loss: 0.4010 - accuracy: 0.7134 - val_loss: 0.4101 - val_accuracy: 0.7171 - 7s/epoch - 71ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 3 - validation_data f1_score: 0.7163
# 97/97 - 3s - loss: 0.3166 - accuracy: 0.7798 - val_loss: 0.3766 - val_accuracy: 0.7523 - 3s/epoch - 34ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 4 - validation_data f1_score: 0.7015
# 97/97 - 4s - loss: 0.2348 - accuracy: 0.8337 - val_loss: 0.3993 - val_accuracy: 0.7416 - 4s/epoch - 43ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7247
# 97/97 - 2s - loss: 0.1804 - accuracy: 0.8622 - val_loss: 0.4257 - val_accuracy: 0.7385 - 2s/epoch - 26ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 6 - validation_data f1_score: 0.7825
# 97/97 - 2s - loss: 0.1228 - accuracy: 0.9160 - val_loss: 0.4244 - val_accuracy: 0.7859 - 2s/epoch - 24ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 7 - validation_data f1_score: 0.7746
# 97/97 - 2s - loss: 0.0816 - accuracy: 0.9585 - val_loss: 0.4385 - val_accuracy: 0.7798 - 2s/epoch - 22ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 8 - validation_data f1_score: 0.7925
# 97/97 - 3s - loss: 0.0466 - accuracy: 0.9773 - val_loss: 0.4741 - val_accuracy: 0.7936 - 3s/epoch - 28ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 9 - validation_data f1_score: 0.7625
# 97/97 - 3s - loss: 0.0337 - accuracy: 0.9828 - val_loss: 0.5061 - val_accuracy: 0.7645 - 3s/epoch - 31ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 10 - validation_data f1_score: 0.7881
# 97/97 - 2s - loss: 0.0372 - accuracy: 0.9818 - val_loss: 0.5289 - val_accuracy: 0.7936 - 2s/epoch - 22ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7873
# 97/97 - 2s - loss: 0.0213 - accuracy: 0.9896 - val_loss: 0.5376 - val_accuracy: 0.7920 - 2s/epoch - 24ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 12 - validation_data f1_score: 0.7907
# 97/97 - 2s - loss: 0.0278 - accuracy: 0.9838 - val_loss: 0.5700 - val_accuracy: 0.7966 - 2s/epoch - 25ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 13 - validation_data f1_score: 0.7788
# 97/97 - 2s - loss: 0.0164 - accuracy: 0.9925 - val_loss: 0.5488 - val_accuracy: 0.7829 - 2s/epoch - 22ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 14 - validation_data f1_score: 0.7939
# 97/97 - 2s - loss: 0.0129 - accuracy: 0.9935 - val_loss: 0.5405 - val_accuracy: 0.7951 - 2s/epoch - 21ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 15 - validation_data f1_score: 0.7825
# 97/97 - 3s - loss: 0.0122 - accuracy: 0.9942 - val_loss: 0.5493 - val_accuracy: 0.7813 - 3s/epoch - 29ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 16 - validation_data f1_score: 0.7965
# 97/97 - 2s - loss: 0.0081 - accuracy: 0.9964 - val_loss: 0.5734 - val_accuracy: 0.7997 - 2s/epoch - 23ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 17 - validation_data f1_score: 0.7880
# 97/97 - 3s - loss: 0.0136 - accuracy: 0.9929 - val_loss: 0.5485 - val_accuracy: 0.7905 - 3s/epoch - 27ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 18 - validation_data f1_score: 0.8035
# 97/97 - 2s - loss: 0.0078 - accuracy: 0.9964 - val_loss: 0.5390 - val_accuracy: 0.8043 - 2s/epoch - 22ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 19 - validation_data f1_score: 0.8044
# 97/97 - 2s - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.6016 - val_accuracy: 0.8089 - 2s/epoch - 18ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 20 - validation_data f1_score: 0.7530
# 97/97 - 2s - loss: 0.0102 - accuracy: 0.9948 - val_loss: 0.5972 - val_accuracy: 0.7492 - 2s/epoch - 20ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.55      0.58      0.56        81
#      neutral       0.81      0.74      0.78       388
#     positive       0.61      0.70      0.65       185
#
#     accuracy                           0.71       654
#    macro avg       0.66      0.68      0.66       654
# weighted avg       0.72      0.71      0.71       654
#
# Test F1 Score: 0.7144319143729545

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=5.0, alpha=0.7)
# Out:
# Finishing last run (ID:kt36cz9b) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.155 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.013956…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▅▅▆▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▄▄▇▆▇▅▇▇▇▇▇▆▇▇██▅</td></tr><tr><td>val_f1_score</td><td>▁▃▅▄▅▇▇█▆▇▇▇▇█▇█▇██▆</td></tr><tr><td>val_loss</td><td>▃▂▁▂▃▂▃▄▅▆▆▇▆▆▆▇▆▆██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99481</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.37657</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.01021</td></tr><tr><td>test_f1_score</td><td>0.71443</td></tr><tr><td>val_accuracy</td><td>0.74924</td></tr><tr><td>val_f1_score</td><td>0.75297</td></tr><tr><td>val_loss</td><td>0.59719</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=5.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/kt36cz9b' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/kt36cz9b</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_161112-kt36cz9b/logs</code>
# Successfully finished last run (ID:kt36cz9b). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_161259-4a11ld17</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/4a11ld17' target="_blank">LSTM Distill t=5.0 a=0.7</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/4a11ld17' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/4a11ld17</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 25ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 7ms/step
# Epoch: 1 - validation_data f1_score: 0.6251
# 97/97 - 19s - loss: 0.5198 - accuracy: 0.6235 - val_loss: 0.4500 - val_accuracy: 0.6774 - 19s/epoch - 198ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 2 - validation_data f1_score: 0.7063
# 97/97 - 6s - loss: 0.3863 - accuracy: 0.7202 - val_loss: 0.3871 - val_accuracy: 0.7508 - 6s/epoch - 62ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 3 - validation_data f1_score: 0.7002
# 97/97 - 5s - loss: 0.2786 - accuracy: 0.8077 - val_loss: 0.4008 - val_accuracy: 0.7401 - 5s/epoch - 49ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 4 - validation_data f1_score: 0.7350
# 97/97 - 4s - loss: 0.2078 - accuracy: 0.8479 - val_loss: 0.3893 - val_accuracy: 0.7554 - 4s/epoch - 37ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7518
# 97/97 - 3s - loss: 0.1963 - accuracy: 0.8635 - val_loss: 0.3918 - val_accuracy: 0.7584 - 3s/epoch - 31ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 6 - validation_data f1_score: 0.7684
# 97/97 - 3s - loss: 0.1122 - accuracy: 0.9342 - val_loss: 0.4083 - val_accuracy: 0.7722 - 3s/epoch - 29ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 7 - validation_data f1_score: 0.7648
# 97/97 - 3s - loss: 0.0822 - accuracy: 0.9536 - val_loss: 0.4434 - val_accuracy: 0.7661 - 3s/epoch - 30ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 8 - validation_data f1_score: 0.7963
# 97/97 - 2s - loss: 0.0457 - accuracy: 0.9741 - val_loss: 0.4579 - val_accuracy: 0.8012 - 2s/epoch - 26ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 9 - validation_data f1_score: 0.7749
# 97/97 - 2s - loss: 0.0363 - accuracy: 0.9802 - val_loss: 0.4585 - val_accuracy: 0.7752 - 2s/epoch - 24ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 10 - validation_data f1_score: 0.7778
# 97/97 - 3s - loss: 0.0264 - accuracy: 0.9861 - val_loss: 0.4915 - val_accuracy: 0.7813 - 3s/epoch - 26ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7706
# 97/97 - 2s - loss: 0.0201 - accuracy: 0.9903 - val_loss: 0.5318 - val_accuracy: 0.7768 - 2s/epoch - 24ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 12 - validation_data f1_score: 0.7622
# 97/97 - 2s - loss: 0.0187 - accuracy: 0.9903 - val_loss: 0.5476 - val_accuracy: 0.7599 - 2s/epoch - 24ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 13 - validation_data f1_score: 0.7645
# 97/97 - 2s - loss: 0.0149 - accuracy: 0.9919 - val_loss: 0.6324 - val_accuracy: 0.7691 - 2s/epoch - 23ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 14 - validation_data f1_score: 0.7687
# 97/97 - 2s - loss: 0.0242 - accuracy: 0.9880 - val_loss: 0.5575 - val_accuracy: 0.7722 - 2s/epoch - 24ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 15 - validation_data f1_score: 0.7747
# 97/97 - 2s - loss: 0.0126 - accuracy: 0.9942 - val_loss: 0.5861 - val_accuracy: 0.7752 - 2s/epoch - 23ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 16 - validation_data f1_score: 0.7892
# 97/97 - 2s - loss: 0.0125 - accuracy: 0.9938 - val_loss: 0.5655 - val_accuracy: 0.7951 - 2s/epoch - 20ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 17 - validation_data f1_score: 0.7754
# 97/97 - 3s - loss: 0.0079 - accuracy: 0.9964 - val_loss: 0.5744 - val_accuracy: 0.7783 - 3s/epoch - 27ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 18 - validation_data f1_score: 0.7760
# 97/97 - 2s - loss: 0.0047 - accuracy: 0.9974 - val_loss: 0.6618 - val_accuracy: 0.7829 - 2s/epoch - 24ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 19 - validation_data f1_score: 0.7878
# 97/97 - 2s - loss: 0.0084 - accuracy: 0.9945 - val_loss: 0.5990 - val_accuracy: 0.7936 - 2s/epoch - 22ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 20 - validation_data f1_score: 0.7722
# 97/97 - 2s - loss: 0.0039 - accuracy: 0.9981 - val_loss: 0.6133 - val_accuracy: 0.7737 - 2s/epoch - 22ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.69      0.54      0.61        81
#      neutral       0.81      0.84      0.82       388
#     positive       0.65      0.65      0.65       185
#
#     accuracy                           0.75       654
#    macro avg       0.71      0.68      0.69       654
# weighted avg       0.75      0.75      0.75       654
#
# Test F1 Score: 0.7480835115462324

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %%
lstm_model, lstm_history, lstm_f1_scores = train_lstm_distilled(temperature=5.0, alpha=0.3)
# Out:
# Finishing last run (ID:4a11ld17) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▅▅▇▇█████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▆▆▆█▇▇▇▆▆▆▇█▇▇█▆</td></tr><tr><td>val_f1_score</td><td>▁▄▄▅▆▇▇█▇▇▇▇▇▇▇█▇▇█▇</td></tr><tr><td>val_loss</td><td>▃▁▁▁▁▂▂▃▃▄▅▅▇▅▆▆▆█▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99805</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.38707</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.00388</td></tr><tr><td>test_f1_score</td><td>0.74808</td></tr><tr><td>val_accuracy</td><td>0.7737</td></tr><tr><td>val_f1_score</td><td>0.77218</td></tr><tr><td>val_loss</td><td>0.61329</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LSTM Distill t=5.0 a=0.7</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/4a11ld17' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/4a11ld17</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_161259-4a11ld17/logs</code>
# Successfully finished last run (ID:4a11ld17). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_161441-c7yegvy8</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/c7yegvy8' target="_blank">LSTM Distill t=5.0 a=0.3</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/c7yegvy8' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/c7yegvy8</a>
# 386/386 [==============================] - 10s 27ms/step
# 82/82 [==============================] - 2s 26ms/step
# Epoch 1/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 1s 6ms/step
# Epoch: 1 - validation_data f1_score: 0.6285
# 97/97 - 20s - loss: 0.5185 - accuracy: 0.6326 - val_loss: 0.4560 - val_accuracy: 0.6636 - 20s/epoch - 203ms/step
# Epoch 2/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 2 - validation_data f1_score: 0.6945
# 97/97 - 7s - loss: 0.3772 - accuracy: 0.7357 - val_loss: 0.3863 - val_accuracy: 0.7401 - 7s/epoch - 74ms/step
# Epoch 3/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 3 - validation_data f1_score: 0.7033
# 97/97 - 4s - loss: 0.2742 - accuracy: 0.8054 - val_loss: 0.3902 - val_accuracy: 0.7355 - 4s/epoch - 43ms/step
# Epoch 4/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 4 - validation_data f1_score: 0.7145
# 97/97 - 4s - loss: 0.2177 - accuracy: 0.8499 - val_loss: 0.3954 - val_accuracy: 0.7492 - 4s/epoch - 41ms/step
# Epoch 5/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 5 - validation_data f1_score: 0.7815
# 97/97 - 3s - loss: 0.1596 - accuracy: 0.8855 - val_loss: 0.4049 - val_accuracy: 0.7829 - 3s/epoch - 29ms/step
# Epoch 6/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 6 - validation_data f1_score: 0.7555
# 97/97 - 3s - loss: 0.1100 - accuracy: 0.9394 - val_loss: 0.4173 - val_accuracy: 0.7645 - 3s/epoch - 28ms/step
# Epoch 7/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 7 - validation_data f1_score: 0.7829
# 97/97 - 3s - loss: 0.0669 - accuracy: 0.9630 - val_loss: 0.3924 - val_accuracy: 0.7844 - 3s/epoch - 28ms/step
# Epoch 8/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 8 - validation_data f1_score: 0.7718
# 97/97 - 2s - loss: 0.0439 - accuracy: 0.9754 - val_loss: 0.4700 - val_accuracy: 0.7813 - 2s/epoch - 22ms/step
# Epoch 9/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 9 - validation_data f1_score: 0.7646
# 97/97 - 3s - loss: 0.0328 - accuracy: 0.9835 - val_loss: 0.4616 - val_accuracy: 0.7645 - 3s/epoch - 27ms/step
# Epoch 10/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 10 - validation_data f1_score: 0.7884
# 97/97 - 2s - loss: 0.0222 - accuracy: 0.9883 - val_loss: 0.4612 - val_accuracy: 0.7936 - 2s/epoch - 22ms/step
# Epoch 11/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 11 - validation_data f1_score: 0.7707
# 97/97 - 3s - loss: 0.0262 - accuracy: 0.9848 - val_loss: 0.4800 - val_accuracy: 0.7783 - 3s/epoch - 26ms/step
# Epoch 12/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 12 - validation_data f1_score: 0.7871
# 97/97 - 3s - loss: 0.0154 - accuracy: 0.9929 - val_loss: 0.5063 - val_accuracy: 0.7890 - 3s/epoch - 29ms/step
# Epoch 13/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 13 - validation_data f1_score: 0.7866
# 97/97 - 2s - loss: 0.0200 - accuracy: 0.9896 - val_loss: 0.5358 - val_accuracy: 0.7951 - 2s/epoch - 25ms/step
# Epoch 14/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 14 - validation_data f1_score: 0.7812
# 97/97 - 2s - loss: 0.0142 - accuracy: 0.9929 - val_loss: 0.5145 - val_accuracy: 0.7859 - 2s/epoch - 20ms/step
# Epoch 15/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 15 - validation_data f1_score: 0.7707
# 97/97 - 2s - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.5486 - val_accuracy: 0.7813 - 2s/epoch - 25ms/step
# Epoch 16/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 16 - validation_data f1_score: 0.7835
# 97/97 - 2s - loss: 0.0109 - accuracy: 0.9948 - val_loss: 0.5646 - val_accuracy: 0.7875 - 2s/epoch - 22ms/step
# Epoch 17/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 17 - validation_data f1_score: 0.7847
# 97/97 - 3s - loss: 0.0094 - accuracy: 0.9942 - val_loss: 0.5411 - val_accuracy: 0.7844 - 3s/epoch - 26ms/step
# Epoch 18/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 18 - validation_data f1_score: 0.7811
# 97/97 - 2s - loss: 0.0071 - accuracy: 0.9958 - val_loss: 0.6479 - val_accuracy: 0.7844 - 2s/epoch - 25ms/step
# Epoch 19/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 7ms/step
# Epoch: 19 - validation_data f1_score: 0.7730
# 97/97 - 2s - loss: 0.0143 - accuracy: 0.9922 - val_loss: 0.4915 - val_accuracy: 0.7798 - 2s/epoch - 20ms/step
# Epoch 20/20
#
# Calculating validation F1 score...
# 21/21 [==============================] - 0s 6ms/step
# Epoch: 20 - validation_data f1_score: 0.7816
# 97/97 - 2s - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.5747 - val_accuracy: 0.7844 - 2s/epoch - 19ms/step
# 21/21 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#     negative       0.66      0.46      0.54        81
#      neutral       0.78      0.81      0.80       388
#     positive       0.61      0.64      0.63       185
#
#     accuracy                           0.72       654
#    macro avg       0.69      0.64      0.66       654
# weighted avg       0.72      0.72      0.72       654
#
# Test F1 Score: 0.7179543255564081

# %%
plot_training_process(lstm_history, lstm_f1_scores)

# %% [markdown]
# # BERT

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=1.0, alpha=0.5)
# Out:
# wandb: Currently logged in as: iankelk. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_145432-cxyi98g1</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/cxyi98g1' target="_blank">BERT Distill t=1.0 a=0.5</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/cxyi98g1' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/cxyi98g1</a>
# 386/386 [==============================] - 21s 38ms/step
# 82/82 [==============================] - 5s 30ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.8839 - accuracy: 0.6093
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5808
# 386/386 [==============================] - 70s 118ms/step - loss: 0.8839 - accuracy: 0.6093 - val_loss: 0.7306 - val_accuracy: 0.6820
# Epoch 2/20
# 386/386 [==============================] - ETA: 0s - loss: 0.7339 - accuracy: 0.6829
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6232
# 386/386 [==============================] - 26s 67ms/step - loss: 0.7339 - accuracy: 0.6829 - val_loss: 0.7235 - val_accuracy: 0.7141
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5966 - accuracy: 0.7481
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6022
# 386/386 [==============================] - 26s 66ms/step - loss: 0.5966 - accuracy: 0.7481 - val_loss: 0.8459 - val_accuracy: 0.6789
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.4850 - accuracy: 0.8010
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.5852
# 386/386 [==============================] - 26s 67ms/step - loss: 0.4844 - accuracy: 0.8012 - val_loss: 0.9805 - val_accuracy: 0.6972
# Epoch 5/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3882 - accuracy: 0.8260
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6407
# 386/386 [==============================] - 26s 67ms/step - loss: 0.3877 - accuracy: 0.8262 - val_loss: 0.8514 - val_accuracy: 0.7370
# Epoch 6/20
# 386/386 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8674
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6152
# 386/386 [==============================] - 25s 66ms/step - loss: 0.3119 - accuracy: 0.8674 - val_loss: 0.9115 - val_accuracy: 0.6972
# Epoch 7/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8907
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.5920
# 386/386 [==============================] - 26s 67ms/step - loss: 0.2847 - accuracy: 0.8907 - val_loss: 1.3068 - val_accuracy: 0.6055
# Epoch 8/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2263 - accuracy: 0.9179
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.7099
# 386/386 [==============================] - 27s 69ms/step - loss: 0.2260 - accuracy: 0.9180 - val_loss: 0.8571 - val_accuracy: 0.7462
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9545
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7127
# 386/386 [==============================] - 26s 66ms/step - loss: 0.1409 - accuracy: 0.9546 - val_loss: 0.9311 - val_accuracy: 0.7492
# Epoch 10/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9659
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7187
# 386/386 [==============================] - 26s 68ms/step - loss: 0.1035 - accuracy: 0.9660 - val_loss: 0.9297 - val_accuracy: 0.7630
# Epoch 11/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9802
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7111
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0640 - accuracy: 0.9802 - val_loss: 1.1269 - val_accuracy: 0.7538
# Epoch 12/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9860
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7184
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0506 - accuracy: 0.9861 - val_loss: 1.2148 - val_accuracy: 0.7599
# Epoch 13/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9864
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7263
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0399 - accuracy: 0.9864 - val_loss: 0.9155 - val_accuracy: 0.7691
# Epoch 14/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0394 - accuracy: 0.9873
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7277
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0393 - accuracy: 0.9874 - val_loss: 1.1306 - val_accuracy: 0.7661
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9880
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7006
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 1.2493 - val_accuracy: 0.7661
# Epoch 16/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9942
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7120
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0250 - accuracy: 0.9942 - val_loss: 1.1275 - val_accuracy: 0.7615
# Epoch 17/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9929
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7069
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0273 - accuracy: 0.9929 - val_loss: 1.2974 - val_accuracy: 0.7492
# Epoch 18/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9916
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7095
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 1.2622 - val_accuracy: 0.7538
# Epoch 19/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9938
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7043
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0183 - accuracy: 0.9938 - val_loss: 1.2010 - val_accuracy: 0.7584
# Epoch 20/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9922
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7110
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0226 - accuracy: 0.9922 - val_loss: 1.2929 - val_accuracy: 0.7492
# 82/82 [==============================] - 3s 24ms/step
#               precision    recall  f1-score   support
#
#     negative       0.63      0.59      0.61        81
#      neutral       0.83      0.77      0.80       388
#     positive       0.59      0.70      0.64       185
#
#     accuracy                           0.73       654
#    macro avg       0.68      0.69      0.68       654
# weighted avg       0.74      0.73      0.73       654
#
# F1 Score: 0.7313119399514723

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=1.0, alpha=0.8)
# Out:
# Finishing last run (ID:a8mdepwf) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▅▅▆▆▇▇▇██████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▂▄▆▃▅▇████▇█▇▇▇▇▆</td></tr><tr><td>val_f1_score</td><td>▁▄▅▂▄▆▅▇▇█▇██▇█▇▇▇▇▇</td></tr><tr><td>val_loss</td><td>▂▁▁▅▂▃▄▄▃▅▆▆▅▆▆▇█▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99481</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.66374</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.70552</td></tr><tr><td>loss</td><td>0.01938</td></tr><tr><td>val_accuracy</td><td>0.763</td></tr><tr><td>val_f1_score</td><td>0.70864</td></tr><tr><td>val_loss</td><td>1.33202</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=1.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/a8mdepwf' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/a8mdepwf</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_074303-a8mdepwf/logs</code>
# Successfully finished last run (ID:a8mdepwf). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112660566666616, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_075300-u53cov80</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/u53cov80' target="_blank">BERT Distill t=1.0 a=0.8</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/u53cov80' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/u53cov80</a>
# 386/386 [==============================] - 15s 39ms/step
# 82/82 [==============================] - 2s 30ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.8848 - accuracy: 0.6093
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5658
# 386/386 [==============================] - 65s 107ms/step - loss: 0.8848 - accuracy: 0.6093 - val_loss: 0.7397 - val_accuracy: 0.6758
# Epoch 2/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.7321 - accuracy: 0.6769
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6351
# 386/386 [==============================] - 26s 67ms/step - loss: 0.7320 - accuracy: 0.6767 - val_loss: 0.6700 - val_accuracy: 0.7278
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5901 - accuracy: 0.7549
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6272
# 386/386 [==============================] - 26s 67ms/step - loss: 0.5901 - accuracy: 0.7549 - val_loss: 0.7479 - val_accuracy: 0.7003
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.4587 - accuracy: 0.8039
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6322
# 386/386 [==============================] - 26s 67ms/step - loss: 0.4581 - accuracy: 0.8042 - val_loss: 0.9080 - val_accuracy: 0.7309
# Epoch 5/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3687 - accuracy: 0.8383
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6338
# 386/386 [==============================] - 26s 67ms/step - loss: 0.3682 - accuracy: 0.8385 - val_loss: 0.8382 - val_accuracy: 0.7156
# Epoch 6/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2872 - accuracy: 0.8786
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6749
# 386/386 [==============================] - 26s 67ms/step - loss: 0.2869 - accuracy: 0.8787 - val_loss: 1.0017 - val_accuracy: 0.7110
# Epoch 7/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9193
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6689
# 386/386 [==============================] - 26s 67ms/step - loss: 0.2080 - accuracy: 0.9193 - val_loss: 1.2399 - val_accuracy: 0.6957
# Epoch 8/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9465
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.7203
# 386/386 [==============================] - 27s 70ms/step - loss: 0.1463 - accuracy: 0.9465 - val_loss: 0.7715 - val_accuracy: 0.7599
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0970 - accuracy: 0.9666
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7312
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0969 - accuracy: 0.9666 - val_loss: 1.0250 - val_accuracy: 0.7829
# Epoch 10/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9770
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7214
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 1.1347 - val_accuracy: 0.7783
# Epoch 11/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0408 - accuracy: 0.9860
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7375
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0408 - accuracy: 0.9861 - val_loss: 1.0642 - val_accuracy: 0.7691
# Epoch 12/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9903
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7442
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0349 - accuracy: 0.9903 - val_loss: 1.1576 - val_accuracy: 0.7951
# Epoch 13/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9938
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7359
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0279 - accuracy: 0.9938 - val_loss: 1.2709 - val_accuracy: 0.7783
# Epoch 14/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9874
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7351
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0421 - accuracy: 0.9874 - val_loss: 1.3189 - val_accuracy: 0.7905
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0335 - accuracy: 0.9909
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7192
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0335 - accuracy: 0.9909 - val_loss: 1.1410 - val_accuracy: 0.7676
# Epoch 16/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9958
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7311
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0185 - accuracy: 0.9958 - val_loss: 1.1967 - val_accuracy: 0.7798
# Epoch 17/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9912
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7208
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0350 - accuracy: 0.9912 - val_loss: 1.2439 - val_accuracy: 0.7737
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9912
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7506
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 1.2554 - val_accuracy: 0.7936
# Epoch 19/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9948
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7250
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0196 - accuracy: 0.9948 - val_loss: 1.1953 - val_accuracy: 0.7768
# Epoch 20/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9932
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7228
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0236 - accuracy: 0.9932 - val_loss: 1.0627 - val_accuracy: 0.7722
# 82/82 [==============================] - 3s 22ms/step
#               precision    recall  f1-score   support
#
#     negative       0.67      0.49      0.57        81
#      neutral       0.82      0.79      0.80       388
#     positive       0.59      0.70      0.64       185
#
#     accuracy                           0.72       654
#    macro avg       0.69      0.66      0.67       654
# weighted avg       0.73      0.72      0.73       654
#
# F1 Score: 0.7254020996957873

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=1.0, alpha=0.2)
plot_training_process(distillbert_history, distillbert_f1_scores)
# Out:
# Finishing last run (ID:cxyi98g1) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▄▅▆▆▇▇▇██████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▅▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▄▆▄▅▇▅▁▇▇█▇█████▇▇█▇</td></tr><tr><td>val_f1_score</td><td>▁▃▂▁▄▃▂▇▇█▇███▇▇▇▇▇▇</td></tr><tr><td>val_loss</td><td>▁▁▂▄▃▃█▃▃▃▆▇▃▆▇▆█▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99222</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.72353</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.73131</td></tr><tr><td>loss</td><td>0.02258</td></tr><tr><td>val_accuracy</td><td>0.74924</td></tr><tr><td>val_f1_score</td><td>0.71095</td></tr><tr><td>val_loss</td><td>1.29285</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=1.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/cxyi98g1' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/cxyi98g1</a><br/> View job at <a href='https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v5' target="_blank">https://wandb.ai/iankelk/bert-sentiment/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEwODg2OTYzNw==/version_details/v5</a><br/>Synced 5 W&B file(s), 1 media file(s), 6 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_145432-cxyi98g1/logs</code>
# Successfully finished last run (ID:cxyi98g1). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_150436-v0fk6tul</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/v0fk6tul' target="_blank">BERT Distill t=1.0 a=0.2</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/v0fk6tul' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/v0fk6tul</a>
# 386/386 [==============================] - 15s 38ms/step
# 82/82 [==============================] - 3s 30ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.8765 - accuracy: 0.6141
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5646
# 386/386 [==============================] - 62s 102ms/step - loss: 0.8765 - accuracy: 0.6141 - val_loss: 0.7383 - val_accuracy: 0.6758
# Epoch 2/20
# 386/386 [==============================] - ETA: 0s - loss: 0.7278 - accuracy: 0.6809
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6288
# 386/386 [==============================] - 25s 64ms/step - loss: 0.7278 - accuracy: 0.6809 - val_loss: 0.6581 - val_accuracy: 0.7141
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5823 - accuracy: 0.7497
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.5951
# 386/386 [==============================] - 25s 64ms/step - loss: 0.5823 - accuracy: 0.7497 - val_loss: 0.7840 - val_accuracy: 0.6544
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.4631 - accuracy: 0.8003
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6061
# 386/386 [==============================] - 25s 64ms/step - loss: 0.4625 - accuracy: 0.8006 - val_loss: 0.9196 - val_accuracy: 0.7141
# Epoch 5/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3713 - accuracy: 0.8315
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6461
# 386/386 [==============================] - 25s 64ms/step - loss: 0.3709 - accuracy: 0.8317 - val_loss: 0.7948 - val_accuracy: 0.7462
# Epoch 6/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3035 - accuracy: 0.8666
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6856
# 386/386 [==============================] - 25s 65ms/step - loss: 0.3032 - accuracy: 0.8667 - val_loss: 0.7399 - val_accuracy: 0.7385
# Epoch 7/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9014
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6854
# 386/386 [==============================] - 26s 66ms/step - loss: 0.2424 - accuracy: 0.9014 - val_loss: 0.9968 - val_accuracy: 0.7156
# Epoch 8/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1947 - accuracy: 0.9292
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.6924
# 386/386 [==============================] - 25s 64ms/step - loss: 0.1945 - accuracy: 0.9293 - val_loss: 1.0639 - val_accuracy: 0.7049
# Epoch 9/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9543
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7412
# 386/386 [==============================] - 26s 67ms/step - loss: 0.1355 - accuracy: 0.9543 - val_loss: 0.8035 - val_accuracy: 0.7798
# Epoch 10/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0945 - accuracy: 0.9653
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7398
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0944 - accuracy: 0.9653 - val_loss: 0.9669 - val_accuracy: 0.7798
# Epoch 11/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9789
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7247
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0630 - accuracy: 0.9789 - val_loss: 0.9906 - val_accuracy: 0.7722
# Epoch 12/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9873
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7118
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0456 - accuracy: 0.9874 - val_loss: 1.0814 - val_accuracy: 0.7324
# Epoch 13/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9883
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7251
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0445 - accuracy: 0.9883 - val_loss: 1.0386 - val_accuracy: 0.7722
# Epoch 14/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9916
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7275
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 1.0980 - val_accuracy: 0.7829
# Epoch 15/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9935
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7184
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 1.2860 - val_accuracy: 0.7630
# Epoch 16/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9958
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7105
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 1.3690 - val_accuracy: 0.7676
# Epoch 17/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9925
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7214
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0251 - accuracy: 0.9925 - val_loss: 1.2443 - val_accuracy: 0.7691
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9893
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.6759
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0328 - accuracy: 0.9893 - val_loss: 1.3547 - val_accuracy: 0.7462
# Epoch 19/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9922
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7252
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 1.1103 - val_accuracy: 0.7630
# Epoch 20/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 0.9961
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7080
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0209 - accuracy: 0.9961 - val_loss: 1.2802 - val_accuracy: 0.7508
# 82/82 [==============================] - 3s 21ms/step
#               precision    recall  f1-score   support
#
#     negative       0.76      0.52      0.62        81
#      neutral       0.80      0.82      0.81       388
#     positive       0.61      0.65      0.63       185
#
#     accuracy                           0.74       654
#    macro avg       0.72      0.67      0.69       654
# weighted avg       0.74      0.74      0.74       654
#
# F1 Score: 0.7366129311692233

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=2.0, alpha=0.5)
# Out:
# Finishing last run (ID:3prvkxfm) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.018 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.111192…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▅▆▆▇▇▇███████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▅▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▂▆▆▇▅▃▇▆▇▅▇▇▇▇█▇▇▇</td></tr><tr><td>val_f1_score</td><td>▁▅▄▅▇▇▇▆███▇████████</td></tr><tr><td>val_loss</td><td>▂▁▃▂▄▄▅▅▅▄▇▆▆██▇▆▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99611</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.65567</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.71556</td></tr><tr><td>loss</td><td>0.01647</td></tr><tr><td>val_accuracy</td><td>0.763</td></tr><tr><td>val_f1_score</td><td>0.72967</td></tr><tr><td>val_loss</td><td>1.27478</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=1.0 a=0.2</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/3prvkxfm' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/3prvkxfm</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_080258-3prvkxfm/logs</code>
# Successfully finished last run (ID:3prvkxfm). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_081253-bezgh6en</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/bezgh6en' target="_blank">BERT Distill t=2.0 a=0.5</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/bezgh6en' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/bezgh6en</a>
# 386/386 [==============================] - 15s 38ms/step
# 82/82 [==============================] - 3s 31ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.8113 - accuracy: 0.6119
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5577
# 386/386 [==============================] - 63s 106ms/step - loss: 0.8113 - accuracy: 0.6119 - val_loss: 0.6620 - val_accuracy: 0.6697
# Epoch 2/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.6694 - accuracy: 0.6812
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6265
# 386/386 [==============================] - 26s 68ms/step - loss: 0.6695 - accuracy: 0.6809 - val_loss: 0.5941 - val_accuracy: 0.7187
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5430 - accuracy: 0.7474
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6131
# 386/386 [==============================] - 26s 67ms/step - loss: 0.5430 - accuracy: 0.7474 - val_loss: 0.6318 - val_accuracy: 0.7187
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.4246 - accuracy: 0.8003
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6310
# 386/386 [==============================] - 29s 76ms/step - loss: 0.4241 - accuracy: 0.8006 - val_loss: 0.7396 - val_accuracy: 0.7339
# Epoch 5/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3378 - accuracy: 0.8331
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6591
# 386/386 [==============================] - 28s 73ms/step - loss: 0.3374 - accuracy: 0.8333 - val_loss: 0.7209 - val_accuracy: 0.7416
# Epoch 6/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.8787
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6930
# 386/386 [==============================] - 27s 70ms/step - loss: 0.2627 - accuracy: 0.8787 - val_loss: 0.7168 - val_accuracy: 0.7538
# Epoch 7/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2417 - accuracy: 0.9039
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6597
# 386/386 [==============================] - 27s 70ms/step - loss: 0.2423 - accuracy: 0.9037 - val_loss: 1.0505 - val_accuracy: 0.6636
# Epoch 8/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9264
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.7171
# 386/386 [==============================] - 27s 69ms/step - loss: 0.1936 - accuracy: 0.9264 - val_loss: 0.5753 - val_accuracy: 0.7737
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.9519
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7056
# 386/386 [==============================] - 26s 68ms/step - loss: 0.1261 - accuracy: 0.9520 - val_loss: 0.6779 - val_accuracy: 0.7645
# Epoch 10/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9647
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7274
# 386/386 [==============================] - 26s 68ms/step - loss: 0.1005 - accuracy: 0.9647 - val_loss: 0.7123 - val_accuracy: 0.7844
# Epoch 11/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9828
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7141
# 386/386 [==============================] - 26s 68ms/step - loss: 0.0591 - accuracy: 0.9828 - val_loss: 0.7558 - val_accuracy: 0.7706
# Epoch 12/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9847
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7135
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0561 - accuracy: 0.9848 - val_loss: 0.7839 - val_accuracy: 0.7584
# Epoch 13/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9877
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.6767
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0437 - accuracy: 0.9877 - val_loss: 0.9730 - val_accuracy: 0.6911
# Epoch 14/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9916
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7040
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0378 - accuracy: 0.9916 - val_loss: 0.9598 - val_accuracy: 0.7676
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9870
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7130
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0440 - accuracy: 0.9870 - val_loss: 0.8607 - val_accuracy: 0.7599
# Epoch 16/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0400 - accuracy: 0.9896
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7265
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0400 - accuracy: 0.9896 - val_loss: 0.8283 - val_accuracy: 0.7737
# Epoch 17/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0283 - accuracy: 0.9942
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7125
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0283 - accuracy: 0.9942 - val_loss: 0.9496 - val_accuracy: 0.7492
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9925
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7181
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0341 - accuracy: 0.9925 - val_loss: 0.9260 - val_accuracy: 0.7722
# Epoch 19/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9916
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7192
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0388 - accuracy: 0.9916 - val_loss: 0.8901 - val_accuracy: 0.7844
# Epoch 20/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9938
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7165
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0326 - accuracy: 0.9938 - val_loss: 0.8478 - val_accuracy: 0.7676
# 82/82 [==============================] - 3s 21ms/step
#               precision    recall  f1-score   support
#
#     negative       0.78      0.52      0.62        81
#      neutral       0.79      0.84      0.82       388
#     positive       0.58      0.59      0.59       185
#
#     accuracy                           0.73       654
#    macro avg       0.72      0.65      0.68       654
# weighted avg       0.73      0.73      0.73       654
#
# F1 Score: 0.7275830261833408

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=2.0, alpha=0.8)
# Out:
# Finishing last run (ID:bezgh6en) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▃▄▅▆▆▇▇▇██████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▄▅▆▆▁▇▇█▇▆▃▇▇▇▆▇█▇</td></tr><tr><td>val_f1_score</td><td>▁▄▃▄▅▇▅█▇█▇▇▆▇▇█▇███</td></tr><tr><td>val_loss</td><td>▂▁▂▃▃▃█▁▃▃▄▄▇▇▅▅▇▆▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99384</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.57529</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.72758</td></tr><tr><td>loss</td><td>0.03258</td></tr><tr><td>val_accuracy</td><td>0.76758</td></tr><tr><td>val_f1_score</td><td>0.7165</td></tr><tr><td>val_loss</td><td>0.8478</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=2.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/bezgh6en' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/bezgh6en</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_081253-bezgh6en/logs</code>
# Successfully finished last run (ID:bezgh6en). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_082257-dl7ryvb0</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/dl7ryvb0' target="_blank">BERT Distill t=2.0 a=0.8</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/dl7ryvb0' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/dl7ryvb0</a>
# 386/386 [==============================] - 15s 38ms/step
# 82/82 [==============================] - 2s 30ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.8017 - accuracy: 0.6141
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5801
# 386/386 [==============================] - 65s 106ms/step - loss: 0.8017 - accuracy: 0.6141 - val_loss: 0.6362 - val_accuracy: 0.6789
# Epoch 2/20
# 386/386 [==============================] - ETA: 0s - loss: 0.6560 - accuracy: 0.6858
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6311
# 386/386 [==============================] - 25s 66ms/step - loss: 0.6560 - accuracy: 0.6858 - val_loss: 0.5912 - val_accuracy: 0.7278
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5387 - accuracy: 0.7532
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.5640
# 386/386 [==============================] - 25s 66ms/step - loss: 0.5387 - accuracy: 0.7532 - val_loss: 0.7649 - val_accuracy: 0.6758
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.4283 - accuracy: 0.7961
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6423
# 386/386 [==============================] - 25s 65ms/step - loss: 0.4278 - accuracy: 0.7964 - val_loss: 0.6206 - val_accuracy: 0.7385
# Epoch 5/20
# 386/386 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8359
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6388
# 386/386 [==============================] - 25s 65ms/step - loss: 0.3451 - accuracy: 0.8359 - val_loss: 0.8395 - val_accuracy: 0.6927
# Epoch 6/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2646 - accuracy: 0.8773
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.7049
# 386/386 [==============================] - 25s 65ms/step - loss: 0.2643 - accuracy: 0.8774 - val_loss: 0.7802 - val_accuracy: 0.7339
# Epoch 7/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1954 - accuracy: 0.9153
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6431
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1952 - accuracy: 0.9154 - val_loss: 0.9890 - val_accuracy: 0.6453
# Epoch 8/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1506 - accuracy: 0.9403
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.6941
# 386/386 [==============================] - 25s 65ms/step - loss: 0.1504 - accuracy: 0.9403 - val_loss: 0.8130 - val_accuracy: 0.7171
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9568
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7442
# 386/386 [==============================] - 25s 65ms/step - loss: 0.1194 - accuracy: 0.9569 - val_loss: 0.7008 - val_accuracy: 0.7768
# Epoch 10/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9773
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7357
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0730 - accuracy: 0.9773 - val_loss: 0.7625 - val_accuracy: 0.7813
# Epoch 11/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9874
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7252
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0508 - accuracy: 0.9874 - val_loss: 0.8110 - val_accuracy: 0.7813
# Epoch 12/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9831
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7342
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0597 - accuracy: 0.9831 - val_loss: 0.7661 - val_accuracy: 0.7722
# Epoch 13/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0478 - accuracy: 0.9847
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7099
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0478 - accuracy: 0.9848 - val_loss: 0.7922 - val_accuracy: 0.7752
# Epoch 14/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9887
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7101
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0507 - accuracy: 0.9887 - val_loss: 0.8511 - val_accuracy: 0.7554
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9890
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7125
# 386/386 [==============================] - 26s 68ms/step - loss: 0.0414 - accuracy: 0.9890 - val_loss: 0.7716 - val_accuracy: 0.7508
# Epoch 16/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0413 - accuracy: 0.9893
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7059
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0412 - accuracy: 0.9893 - val_loss: 0.8833 - val_accuracy: 0.7599
# Epoch 17/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9961
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7188
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0295 - accuracy: 0.9961 - val_loss: 0.8790 - val_accuracy: 0.7752
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9981
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7150
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0219 - accuracy: 0.9981 - val_loss: 0.9652 - val_accuracy: 0.7691
# Epoch 19/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9974
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7176
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0243 - accuracy: 0.9974 - val_loss: 1.0234 - val_accuracy: 0.7722
# Epoch 20/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9834
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.6981
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0630 - accuracy: 0.9835 - val_loss: 0.9345 - val_accuracy: 0.7645
# 82/82 [==============================] - 3s 22ms/step
#               precision    recall  f1-score   support
#
#     negative       0.77      0.41      0.53        81
#      neutral       0.76      0.88      0.82       388
#     positive       0.62      0.55      0.58       185
#
#     accuracy                           0.73       654
#    macro avg       0.72      0.61      0.64       654
# weighted avg       0.72      0.73      0.71       654
#
# F1 Score: 0.7145204751093641

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=2.0, alpha=0.2)
# Out:
# Finishing last run (ID:dl7ryvb0) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▄▅▆▆▇▇███████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▃▅▃▆▃▆▁▅█████▇▆▇█▇█▇</td></tr><tr><td>val_f1_score</td><td>▂▄▁▄▄▆▄▆██▇█▇▇▇▇▇▇▇▆</td></tr><tr><td>val_loss</td><td>▂▁▄▁▅▄▇▅▃▄▅▄▄▅▄▆▆▇█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98346</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.59124</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.71452</td></tr><tr><td>loss</td><td>0.06303</td></tr><tr><td>val_accuracy</td><td>0.76453</td></tr><tr><td>val_f1_score</td><td>0.69813</td></tr><tr><td>val_loss</td><td>0.93446</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=2.0 a=0.8</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/dl7ryvb0' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/dl7ryvb0</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_082257-dl7ryvb0/logs</code>
# Successfully finished last run (ID:dl7ryvb0). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_083238-n22cj3ua</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/n22cj3ua' target="_blank">BERT Distill t=2.0 a=0.2</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/n22cj3ua' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/n22cj3ua</a>
# 386/386 [==============================] - 15s 38ms/step
# 82/82 [==============================] - 2s 30ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 0.6122
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5647
# 386/386 [==============================] - 63s 105ms/step - loss: 0.8120 - accuracy: 0.6122 - val_loss: 0.6597 - val_accuracy: 0.6743
# Epoch 2/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.6701 - accuracy: 0.6808
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6330
# 386/386 [==============================] - 27s 69ms/step - loss: 0.6705 - accuracy: 0.6806 - val_loss: 0.5892 - val_accuracy: 0.7095
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5307 - accuracy: 0.7523
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6510
# 386/386 [==============================] - 26s 67ms/step - loss: 0.5307 - accuracy: 0.7523 - val_loss: 0.5798 - val_accuracy: 0.7416
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8123
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.5631
# 386/386 [==============================] - 25s 66ms/step - loss: 0.4029 - accuracy: 0.8126 - val_loss: 0.8700 - val_accuracy: 0.6835
# Epoch 5/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3417 - accuracy: 0.8370
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6477
# 386/386 [==============================] - 26s 66ms/step - loss: 0.3413 - accuracy: 0.8372 - val_loss: 0.6352 - val_accuracy: 0.7355
# Epoch 6/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2673 - accuracy: 0.8833
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6678
# 386/386 [==============================] - 25s 65ms/step - loss: 0.2673 - accuracy: 0.8833 - val_loss: 0.9746 - val_accuracy: 0.6820
# Epoch 7/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2094 - accuracy: 0.9195
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6947
# 386/386 [==============================] - 25s 65ms/step - loss: 0.2095 - accuracy: 0.9193 - val_loss: 0.8061 - val_accuracy: 0.7217
# Epoch 8/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9400
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.6812
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1678 - accuracy: 0.9400 - val_loss: 0.8234 - val_accuracy: 0.7018
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9555
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.6985
# 386/386 [==============================] - 26s 66ms/step - loss: 0.1311 - accuracy: 0.9556 - val_loss: 0.7897 - val_accuracy: 0.7431
# Epoch 10/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9627
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7185
# 386/386 [==============================] - 26s 66ms/step - loss: 0.1141 - accuracy: 0.9627 - val_loss: 0.7914 - val_accuracy: 0.7630
# Epoch 11/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9721
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.6832
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0946 - accuracy: 0.9721 - val_loss: 0.8666 - val_accuracy: 0.7554
# Epoch 12/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9815
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7057
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0648 - accuracy: 0.9815 - val_loss: 0.7944 - val_accuracy: 0.7599
# Epoch 13/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9841
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7110
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0571 - accuracy: 0.9841 - val_loss: 0.9400 - val_accuracy: 0.7661
# Epoch 14/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9861
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7250
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0561 - accuracy: 0.9861 - val_loss: 0.9017 - val_accuracy: 0.7737
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9883
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7271
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0493 - accuracy: 0.9883 - val_loss: 0.8373 - val_accuracy: 0.7645
# Epoch 16/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9912
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7213
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0425 - accuracy: 0.9912 - val_loss: 0.8793 - val_accuracy: 0.7737
# Epoch 17/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9887
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7083
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0450 - accuracy: 0.9887 - val_loss: 0.8750 - val_accuracy: 0.7523
# Epoch 18/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9903
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7202
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0422 - accuracy: 0.9903 - val_loss: 0.8932 - val_accuracy: 0.7798
# Epoch 19/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9922
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7080
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0388 - accuracy: 0.9922 - val_loss: 0.8899 - val_accuracy: 0.7676
# Epoch 20/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9903
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7201
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0412 - accuracy: 0.9903 - val_loss: 0.9150 - val_accuracy: 0.7691
# 82/82 [==============================] - 3s 23ms/step
#               precision    recall  f1-score   support
#
#     negative       0.79      0.33      0.47        81
#      neutral       0.80      0.82      0.81       388
#     positive       0.54      0.64      0.58       185
#
#     accuracy                           0.71       654
#    macro avg       0.71      0.60      0.62       654
# weighted avg       0.72      0.71      0.70       654
#
# F1 Score: 0.7021154769267687

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=3.0, alpha=0.5)
# Out:
# Finishing last run (ID:n22cj3ua) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▅▅▆▇▇▇▇██████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▂▅▂▄▃▆▇▆▇▇█▇█▆█▇▇</td></tr><tr><td>val_f1_score</td><td>▁▄▅▁▅▅▇▆▇█▆▇▇███▇█▇█</td></tr><tr><td>val_loss</td><td>▂▁▁▆▂█▅▅▅▅▆▅▇▇▆▆▆▇▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99027</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.57982</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.70212</td></tr><tr><td>loss</td><td>0.04124</td></tr><tr><td>val_accuracy</td><td>0.76911</td></tr><tr><td>val_f1_score</td><td>0.72008</td></tr><tr><td>val_loss</td><td>0.91503</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=2.0 a=0.2</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/n22cj3ua' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/n22cj3ua</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231022_083238-n22cj3ua/logs</code>
# Successfully finished last run (ID:n22cj3ua). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_084225-quucjtug</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/quucjtug' target="_blank">BERT Distill t=3.0 a=0.5</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/quucjtug' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/quucjtug</a>
# 386/386 [==============================] - 14s 37ms/step
# 82/82 [==============================] - 2s 29ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.6174
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5741
# 386/386 [==============================] - 65s 106ms/step - loss: 0.6983 - accuracy: 0.6174 - val_loss: 0.5635 - val_accuracy: 0.6774
# Epoch 2/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.6796
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6303
# 386/386 [==============================] - 25s 65ms/step - loss: 0.5734 - accuracy: 0.6796 - val_loss: 0.5293 - val_accuracy: 0.7141
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.4731 - accuracy: 0.7474
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6344
# 386/386 [==============================] - 25s 66ms/step - loss: 0.4731 - accuracy: 0.7474 - val_loss: 0.5167 - val_accuracy: 0.7263
# Epoch 4/20
# 386/386 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8029
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6373
# 386/386 [==============================] - 26s 66ms/step - loss: 0.3760 - accuracy: 0.8029 - val_loss: 0.5882 - val_accuracy: 0.7385
# Epoch 5/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3079 - accuracy: 0.8451
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6685
# 386/386 [==============================] - 25s 66ms/step - loss: 0.3076 - accuracy: 0.8453 - val_loss: 0.5763 - val_accuracy: 0.7278
# Epoch 6/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2539 - accuracy: 0.8774
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.7142
# 386/386 [==============================] - 25s 66ms/step - loss: 0.2539 - accuracy: 0.8774 - val_loss: 0.6258 - val_accuracy: 0.7462
# Epoch 7/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2060 - accuracy: 0.9108
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6828
# 386/386 [==============================] - 26s 66ms/step - loss: 0.2060 - accuracy: 0.9108 - val_loss: 0.7017 - val_accuracy: 0.6988
# Epoch 8/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1641 - accuracy: 0.9403
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.6946
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1641 - accuracy: 0.9403 - val_loss: 0.6831 - val_accuracy: 0.7095
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9604
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7378
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1225 - accuracy: 0.9604 - val_loss: 0.5536 - val_accuracy: 0.7920
# Epoch 10/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9756
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7371
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0939 - accuracy: 0.9757 - val_loss: 0.5740 - val_accuracy: 0.7920
# Epoch 11/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9789
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7122
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0923 - accuracy: 0.9789 - val_loss: 0.6441 - val_accuracy: 0.7752
# Epoch 12/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9805
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7120
# 386/386 [==============================] - 26s 68ms/step - loss: 0.0846 - accuracy: 0.9805 - val_loss: 0.6488 - val_accuracy: 0.7508
# Epoch 13/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9893
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7332
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0700 - accuracy: 0.9893 - val_loss: 0.6124 - val_accuracy: 0.7783
# Epoch 14/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0688 - accuracy: 0.9899
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7318
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0688 - accuracy: 0.9899 - val_loss: 0.6255 - val_accuracy: 0.7722
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9877
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7190
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0677 - accuracy: 0.9877 - val_loss: 0.6252 - val_accuracy: 0.7768
# Epoch 16/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.9929
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7272
# 386/386 [==============================] - 26s 68ms/step - loss: 0.0610 - accuracy: 0.9929 - val_loss: 0.6247 - val_accuracy: 0.7829
# Epoch 17/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0665 - accuracy: 0.9899
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7166
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0665 - accuracy: 0.9899 - val_loss: 0.5888 - val_accuracy: 0.7875
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9955
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7257
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0559 - accuracy: 0.9955 - val_loss: 0.6291 - val_accuracy: 0.7676
# Epoch 19/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9932
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7052
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0591 - accuracy: 0.9932 - val_loss: 0.6958 - val_accuracy: 0.7492
# Epoch 20/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9893
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7296
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0662 - accuracy: 0.9893 - val_loss: 0.6534 - val_accuracy: 0.7706
# 82/82 [==============================] - 3s 21ms/step
#               precision    recall  f1-score   support
#
#     negative       0.75      0.49      0.60        81
#      neutral       0.79      0.87      0.83       388
#     positive       0.65      0.61      0.63       185
#
#     accuracy                           0.75       654
#    macro avg       0.73      0.66      0.68       654
# weighted avg       0.74      0.75      0.74       654
#
# F1 Score: 0.7409675704223557

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=3.0, alpha=0.8)
# Out:
# Finishing last run (ID:quucjtug) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▃▄▅▆▆▇▇███████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▄▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▄▅▂▃██▇▅▇▇▇▇█▇▅▇</td></tr><tr><td>val_f1_score</td><td>▁▃▄▄▅▇▆▆██▇▇██▇█▇▇▇█</td></tr><tr><td>val_loss</td><td>▃▁▁▄▃▅█▇▂▃▆▆▅▅▅▅▄▅█▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.9893</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.51674</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.74097</td></tr><tr><td>loss</td><td>0.06623</td></tr><tr><td>val_accuracy</td><td>0.77064</td></tr><tr><td>val_f1_score</td><td>0.72961</td></tr><tr><td>val_loss</td><td>0.65339</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=3.0 a=0.5</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/quucjtug' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/quucjtug</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_084225-quucjtug/logs</code>
# Successfully finished last run (ID:quucjtug). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_085214-ao81o3uz</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/ao81o3uz' target="_blank">BERT Distill t=3.0 a=0.8</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/ao81o3uz' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/ao81o3uz</a>
# 386/386 [==============================] - 14s 37ms/step
# 82/82 [==============================] - 2s 29ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.6992 - accuracy: 0.6115
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5732
# 386/386 [==============================] - 64s 110ms/step - loss: 0.6992 - accuracy: 0.6115 - val_loss: 0.5597 - val_accuracy: 0.6804
# Epoch 2/20
# 386/386 [==============================] - ETA: 0s - loss: 0.5663 - accuracy: 0.6848
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6438
# 386/386 [==============================] - 26s 67ms/step - loss: 0.5663 - accuracy: 0.6848 - val_loss: 0.5057 - val_accuracy: 0.7294
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.7549
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6458
# 386/386 [==============================] - 26s 66ms/step - loss: 0.4578 - accuracy: 0.7549 - val_loss: 0.5074 - val_accuracy: 0.7370
# Epoch 4/20
# 386/386 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8054
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6505
# 386/386 [==============================] - 25s 66ms/step - loss: 0.3756 - accuracy: 0.8054 - val_loss: 0.5263 - val_accuracy: 0.7416
# Epoch 5/20
# 386/386 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8314
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6687
# 386/386 [==============================] - 26s 67ms/step - loss: 0.3074 - accuracy: 0.8314 - val_loss: 0.6494 - val_accuracy: 0.7141
# Epoch 6/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2617 - accuracy: 0.8610
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6869
# 386/386 [==============================] - 25s 65ms/step - loss: 0.2614 - accuracy: 0.8612 - val_loss: 0.5904 - val_accuracy: 0.7538
# Epoch 7/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2019 - accuracy: 0.9110
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.7161
# 386/386 [==============================] - 25s 65ms/step - loss: 0.2017 - accuracy: 0.9112 - val_loss: 0.5806 - val_accuracy: 0.7645
# Epoch 8/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9334
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.6785
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1708 - accuracy: 0.9335 - val_loss: 0.7510 - val_accuracy: 0.6789
# Epoch 9/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9503
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7235
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1447 - accuracy: 0.9504 - val_loss: 0.5893 - val_accuracy: 0.7446
# Epoch 10/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9688
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7608
# 386/386 [==============================] - 25s 66ms/step - loss: 0.1069 - accuracy: 0.9689 - val_loss: 0.5579 - val_accuracy: 0.7783
# Epoch 11/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9796
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7457
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0850 - accuracy: 0.9796 - val_loss: 0.5865 - val_accuracy: 0.7798
# Epoch 12/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9815
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7326
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0823 - accuracy: 0.9815 - val_loss: 0.6398 - val_accuracy: 0.7615
# Epoch 13/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9877
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.7186
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0694 - accuracy: 0.9877 - val_loss: 0.6180 - val_accuracy: 0.7446
# Epoch 14/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9887
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.7253
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0677 - accuracy: 0.9887 - val_loss: 0.6639 - val_accuracy: 0.7737
# Epoch 15/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9861
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7331
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0747 - accuracy: 0.9861 - val_loss: 0.6196 - val_accuracy: 0.7737
# Epoch 16/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9903
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7275
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0659 - accuracy: 0.9903 - val_loss: 0.6247 - val_accuracy: 0.7630
# Epoch 17/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9861
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7384
# 386/386 [==============================] - 26s 67ms/step - loss: 0.0722 - accuracy: 0.9861 - val_loss: 0.6734 - val_accuracy: 0.7737
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9838
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7295
# 386/386 [==============================] - 25s 66ms/step - loss: 0.0767 - accuracy: 0.9838 - val_loss: 0.6481 - val_accuracy: 0.7752
# Epoch 19/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9867
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7329
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0695 - accuracy: 0.9867 - val_loss: 0.6366 - val_accuracy: 0.7813
# Epoch 20/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9951
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7448
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0559 - accuracy: 0.9951 - val_loss: 0.5910 - val_accuracy: 0.7798
# 82/82 [==============================] - 3s 21ms/step
#               precision    recall  f1-score   support
#
#     negative       0.76      0.51      0.61        81
#      neutral       0.79      0.81      0.80       388
#     positive       0.60      0.64      0.62       185
#
#     accuracy                           0.73       654
#    macro avg       0.72      0.65      0.68       654
# weighted avg       0.73      0.73      0.73       654
#
# F1 Score: 0.7256281888518934

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %%
distillbert_model, distillbert_history, distillbert_f1_scores = train_bert_distilled(temperature=3.0, alpha=0.2)
# Out:
# Finishing last run (ID:v0fk6tul) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▃▄▅▆▆▇▇▇██████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>loss</td><td>█▇▆▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▄▁▄▆▆▄▄██▇▅▇█▇▇▇▆▇▆</td></tr><tr><td>val_f1_score</td><td>▁▄▂▃▄▆▆▆██▇▇▇▇▇▇▇▅▇▇</td></tr><tr><td>val_loss</td><td>▂▁▂▄▂▂▄▅▂▄▄▅▅▅▇█▇█▅▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99611</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.65807</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>f1_score</td><td>0.73661</td></tr><tr><td>loss</td><td>0.02093</td></tr><tr><td>val_accuracy</td><td>0.75076</td></tr><tr><td>val_f1_score</td><td>0.70805</td></tr><tr><td>val_loss</td><td>1.28019</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BERT Distill t=1.0 a=0.2</strong> at: <a href='https://wandb.ai/iankelk/bert-sentiment/runs/v0fk6tul' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/v0fk6tul</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231022_150436-v0fk6tul/logs</code>
# Successfully finished last run (ID:v0fk6tul). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231022_151413-v24fwo4z</code>
# Syncing run <strong><a href='https://wandb.ai/iankelk/bert-sentiment/runs/v24fwo4z' target="_blank">BERT Distill t=3.0 a=0.2</a></strong> to <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iankelk/bert-sentiment' target="_blank">https://wandb.ai/iankelk/bert-sentiment</a>
#  View run at <a href='https://wandb.ai/iankelk/bert-sentiment/runs/v24fwo4z' target="_blank">https://wandb.ai/iankelk/bert-sentiment/runs/v24fwo4z</a>
# 386/386 [==============================] - 14s 37ms/step
# 82/82 [==============================] - 3s 31ms/step
# Epoch 1/20
# 386/386 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.6102
# Calculating validation F1 score...
# Epoch: 1 - validation_data f1_score: 0.5673
# 386/386 [==============================] - 62s 102ms/step - loss: 0.6969 - accuracy: 0.6102 - val_loss: 0.5660 - val_accuracy: 0.6758
# Epoch 2/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.5738 - accuracy: 0.6841
# Calculating validation F1 score...
# Epoch: 2 - validation_data f1_score: 0.6412
# 386/386 [==============================] - 25s 64ms/step - loss: 0.5737 - accuracy: 0.6842 - val_loss: 0.5131 - val_accuracy: 0.7294
# Epoch 3/20
# 386/386 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7500
# Calculating validation F1 score...
# Epoch: 3 - validation_data f1_score: 0.6479
# 386/386 [==============================] - 25s 64ms/step - loss: 0.4640 - accuracy: 0.7500 - val_loss: 0.5201 - val_accuracy: 0.7431
# Epoch 4/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.3791 - accuracy: 0.7942
# Calculating validation F1 score...
# Epoch: 4 - validation_data f1_score: 0.6478
# 386/386 [==============================] - 25s 64ms/step - loss: 0.3787 - accuracy: 0.7944 - val_loss: 0.5525 - val_accuracy: 0.7416
# Epoch 5/20
# 386/386 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8288
# Calculating validation F1 score...
# Epoch: 5 - validation_data f1_score: 0.6318
# 386/386 [==============================] - 25s 64ms/step - loss: 0.3156 - accuracy: 0.8288 - val_loss: 0.5971 - val_accuracy: 0.7309
# Epoch 6/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2628 - accuracy: 0.8627
# Calculating validation F1 score...
# Epoch: 6 - validation_data f1_score: 0.6543
# 386/386 [==============================] - 25s 64ms/step - loss: 0.2625 - accuracy: 0.8628 - val_loss: 0.7137 - val_accuracy: 0.6911
# Epoch 7/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.2393 - accuracy: 0.8909
# Calculating validation F1 score...
# Epoch: 7 - validation_data f1_score: 0.6888
# 386/386 [==============================] - 25s 64ms/step - loss: 0.2390 - accuracy: 0.8911 - val_loss: 0.5955 - val_accuracy: 0.7248
# Epoch 8/20
# 386/386 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9189
# Calculating validation F1 score...
# Epoch: 8 - validation_data f1_score: 0.6980
# 386/386 [==============================] - 25s 64ms/step - loss: 0.2008 - accuracy: 0.9189 - val_loss: 0.5658 - val_accuracy: 0.7278
# Epoch 9/20
# 386/386 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9494
# Calculating validation F1 score...
# Epoch: 9 - validation_data f1_score: 0.7526
# 386/386 [==============================] - 25s 64ms/step - loss: 0.1513 - accuracy: 0.9494 - val_loss: 0.5052 - val_accuracy: 0.7890
# Epoch 10/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9705
# Calculating validation F1 score...
# Epoch: 10 - validation_data f1_score: 0.7349
# 386/386 [==============================] - 25s 64ms/step - loss: 0.1070 - accuracy: 0.9705 - val_loss: 0.5501 - val_accuracy: 0.7920
# Epoch 11/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9789
# Calculating validation F1 score...
# Epoch: 11 - validation_data f1_score: 0.7149
# 386/386 [==============================] - 25s 65ms/step - loss: 0.0933 - accuracy: 0.9789 - val_loss: 0.5711 - val_accuracy: 0.7752
# Epoch 12/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9835
# Calculating validation F1 score...
# Epoch: 12 - validation_data f1_score: 0.7174
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0809 - accuracy: 0.9835 - val_loss: 0.5874 - val_accuracy: 0.7813
# Epoch 13/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9822
# Calculating validation F1 score...
# Epoch: 13 - validation_data f1_score: 0.6951
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0808 - accuracy: 0.9822 - val_loss: 0.6638 - val_accuracy: 0.7477
# Epoch 14/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9851
# Calculating validation F1 score...
# Epoch: 14 - validation_data f1_score: 0.6960
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0777 - accuracy: 0.9851 - val_loss: 0.6494 - val_accuracy: 0.7538
# Epoch 15/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9838
# Calculating validation F1 score...
# Epoch: 15 - validation_data f1_score: 0.7155
# 386/386 [==============================] - 26s 68ms/step - loss: 0.0768 - accuracy: 0.9838 - val_loss: 0.5966 - val_accuracy: 0.7798
# Epoch 16/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0694 - accuracy: 0.9886
# Calculating validation F1 score...
# Epoch: 16 - validation_data f1_score: 0.7115
# 386/386 [==============================] - 26s 66ms/step - loss: 0.0694 - accuracy: 0.9887 - val_loss: 0.5588 - val_accuracy: 0.7859
# Epoch 17/20
# 386/386 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9896
# Calculating validation F1 score...
# Epoch: 17 - validation_data f1_score: 0.7271
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0661 - accuracy: 0.9896 - val_loss: 0.6074 - val_accuracy: 0.7905
# Epoch 18/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9838
# Calculating validation F1 score...
# Epoch: 18 - validation_data f1_score: 0.7271
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0747 - accuracy: 0.9838 - val_loss: 0.6180 - val_accuracy: 0.7722
# Epoch 19/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0615 - accuracy: 0.9935
# Calculating validation F1 score...
# Epoch: 19 - validation_data f1_score: 0.7406
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0615 - accuracy: 0.9935 - val_loss: 0.6133 - val_accuracy: 0.7890
# Epoch 20/20
# 385/386 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9948
# Calculating validation F1 score...
# Epoch: 20 - validation_data f1_score: 0.7240
# 386/386 [==============================] - 25s 64ms/step - loss: 0.0571 - accuracy: 0.9948 - val_loss: 0.5855 - val_accuracy: 0.7798
# 82/82 [==============================] - 3s 22ms/step
#               precision    recall  f1-score   support
#
#     negative       0.78      0.38      0.51        81
#      neutral       0.80      0.82      0.81       388
#     positive       0.56      0.66      0.61       185
#
#     accuracy                           0.72       654
#    macro avg       0.71      0.62      0.64       654
# weighted avg       0.73      0.72      0.71       654
#
# F1 Score: 0.7141278775299905

# %%
plot_training_process(distillbert_history, distillbert_f1_scores)

# %% [markdown]
# # Disconnect from Colab
#
# Since I'm runnning using an upgraded GPU, this disconnects immediately from Colab to stop the usage timer so that I don't continue to use my GPU credits.

# %%
from google.colab import runtime
runtime.unassign()
